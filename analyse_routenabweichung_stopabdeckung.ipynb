# %% [markdown]
# # Routenabweichungsanalyse und Stoppabdeckung
# Nach dem Data Cleaning im Notebook `Application_neustes.ipynb` soll auf Basis dieser Soll- und Ist-Daten eine Analyse über Routenabweichung gemacht werden. Dabei wurde erst mit den EMR Daten geguckt, welche Touren die alle Soll-Stopps abdecken und in der richtigen Reihenfolge abfahren. Da dieser Anteil jedoch nur 14 Touren waren, die teilweise nur 1 oder 2 Stopps pro Tour hatten, haben wir uns dagegen entschieden diese Touren für weitere Analysen zu nutzen und nur diese Statistik aufgestellt und dann die allgemeine Stoppabdeckung der Soll-Stopps untersucht.
#
# Für einen Vergleich wurden dann für dieselbe Analyse auch die PRC Daten verwendet, die allerdings ähnliche Ergebnisse zeigten. Dieses Notebook enthält auch noch Data Cleaning Schritte für die PRC Daten, wo u.a. auch Tournummern zugeordnet wurden.

# %%
import pandas as pd
import numpy as np
from math import radians, sin, cos, asin, sqrt
import json
from collections import defaultdict
import plotly.graph_objects as go
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Einlesen der Daten
# Das sind Daten, die im Data Cleaning Prozess als Endergebniss entstanden sind.

# %%
soll = pd.read_csv('Soll-Daten.csv', dtype=str)
soll.head()
# Out:
#     TOURNR  LKW_KENNZ           FAHRERNAME     TOUR              ANKUNFT  \
# 0  H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374  2026-03-02 06:00:00
# 1  H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374  2026-03-02 06:49:00
# 2  H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374  2026-03-02 07:41:00
# 3  H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374  2026-03-02 08:31:00
# 4  H/42375  OD-TS8050  Szmajdewicz, Marcin  H/42375  2026-03-02 06:00:00
#
#                ABFAHRT     GEOX      GEOY      STOPP_DAUER       DATUM
# 0  2026-03-02 06:30:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 1  2026-03-02 07:19:00  9.99383  53.54751  0 days 00:30:00  2026-03-02
# 2  2026-03-02 08:11:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 3  2026-03-02 09:01:00  9.99383  53.54751  0 days 00:30:00  2026-03-02
# 4  2026-03-02 06:30:00  9.98632  53.52348  0 days 00:30:00  2026-03-02

# %%
ist = pd.read_csv('Ist-Daten.csv', dtype=str)
ist.head()
# Out:
#   Fahrer PIN          Fahrername Formularnummer Richtung Geschwindigkeit  \
# 0     8160.0  Jorczik, Christian           1650        0               0
# 1     8160.0  Jorczik, Christian           1650      131               0
# 2     8160.0  Jorczik, Christian           1650        0               0
# 3     8160.0  Jorczik, Christian           1650        0               0
# 4     8160.0  Jorczik, Christian           1650        0               0
#
#      KM-Stand Gesamtverbrauch Tankfüllstand Breitengrad Längengrad  \
# 0   317003.22             0.0           0.0     53,6677    9,99287
# 1  317021.295             0.0           0.0    53,55026    9,99017
# 2  317028.945             0.0           0.0    53,57519     9,9127
# 3   317066.35             0.0           0.0    53,61828   10,23092
# 4   317080.55             0.0           0.0    53,67164   10,23997
#
#                                             Position  \
# 0  DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1  DE - 20457 Hamburg (Hamburg-Mitte), Alter Wall 32
# 2   DE - 22525 Hamburg (Bahrenfeld), Winsbergring 15
# 3                        DE - 22145 Braak, Waldweg 2
# 4         DE - 22926 Ahrensburg, Manhagener Allee 10
#
#                        Fahrzeug       DATUM KENNZ_CLEAN   TOURNR  \
# 0  OD-TS 8041 - Fahrzeugdetails  2026-03-30   OD-TS8041  H/42647
# 1  OD-TS 8041 - Fahrzeugdetails  2026-03-30   OD-TS8041  H/42647
# 2  OD-TS 8041 - Fahrzeugdetails  2026-03-30   OD-TS8041  H/42647
# 3  OD-TS 8041 - Fahrzeugdetails  2026-03-30   OD-TS8041  H/42647
# 4  OD-TS 8041 - Fahrzeugdetails  2026-03-30   OD-TS8041  H/42647
#
#                Abfahrt              Ankunft
# 0  2026-03-30 06:17:22  2026-03-30 05:18:19
# 1  2026-03-30 06:59:55  2026-03-30 06:59:54
# 2  2026-03-30 07:28:24  2026-03-30 07:28:23
# 3  2026-03-30 08:37:25  2026-03-30 08:37:24
# 4  2026-03-30 09:24:07  2026-03-30 09:24:06

# %% [markdown]
# ## Unnötige Spalte `TOUR` entfernen in soll

# %%
gleich = soll[soll.TOURNR != soll.TOUR]
gleich
# Out:
# Empty DataFrame
# Columns: [TOURNR, LKW_KENNZ, FAHRERNAME, TOUR, ANKUNFT, ABFAHRT, GEOX, GEOY, STOPP_DAUER, DATUM]
# Index: []

# %%
soll = soll.drop('TOUR', axis=1)

# %% [markdown]
# ## Touren mit gleicher Reihenfolge an Stopps filtern
# * Für jede Tour wird aus den Soll-Daten eine geordnete Liste von Stopps gebaut und aus den Ist-Daten eine geordnete Liste von GPS-Punkten
# * Dann läuft die Funktion toursequencematchesstrict(...) über jeden Ist-Punkt und sucht den nächstgelegenen Soll-Stopp
# * Match zählt nur, wenn der Abstand höchstens 300 Meter beträgt
# * Es muss mindestens 80 Prozent Abdeckung bestehen, damit die Touren als "gleich" gelten -> später stellt sich heraus, dass die 80% Abdeckung dasselbe Ergebnis wie 100% liefert
# ### Hilfsfunktionen für Geofencing

# %%
def haversine(lat1, lon1, lat2, lon2):
    """Berechnet den kürzesten Abstand zwischen zwei Punkten auf einer Kugeloberfläche."""
    # Erdradius in Metern
    R = 6371000
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    return 2 * R * asin(sqrt(a))

def parse_decimal_coord(x):
    """Konvertiert eine Koordinate, die als String mit möglichen Tausendertrennzeichen und Komma als Dezimaltrennzeichen vorliegen kann, in einen float-Wert."""
    # komma zu punkt in dezimalzahl
    if pd.isna(x):
        return np.nan
    s = str(x).replace(' ', '').replace('"','')
    s = s.replace(',', '.') if (',' in s and '.' not in s) else s
    return float(s)

MATCH_RADIUS_M = 300  # max Entfernung zwischen Punkten, damit sie als Match gelten (Geofencing-Radius)

# %% [markdown]
# ### Vorverarbeitung Soll-Daten

# %%
# Erwartete Spalten: TOURNR,GEOX,GEOY,ANKUNFT
soll['GEOX'] = soll['GEOX'].astype(str).apply(parse_decimal_coord)
soll['GEOY'] = soll['GEOY'].astype(str).apply(parse_decimal_coord)
soll['ANKUNFT'] = pd.to_datetime(soll['ANKUNFT'], errors='coerce')
soll = soll.sort_values(['TOURNR','ANKUNFT']).reset_index(drop=True)

# Erzeuge für jede TOURNR eine Liste von (lat,lon)
soll_groups = {}
for tournr, g in soll.groupby('TOURNR'):
    coords = list(zip(g['GEOY'].astype(float).tolist(), g['GEOX'].astype(float).tolist()))
    soll_groups[tournr] = coords

# %% [markdown]
# ### Vorverarbeitung Ist-Daten

# %%
# Vorverarbeitung Ist-Daten: Koordinaten und Zeit konvertieren
ist['lat'] = ist['Breitengrad'].apply(parse_decimal_coord)
ist['lon'] = ist['Längengrad'].apply(parse_decimal_coord)
ist['Ankunft'] = pd.to_datetime(ist['Ankunft'], errors='coerce')
ist = ist.sort_values(['TOURNR', 'Ankunft']).reset_index(drop=True)

# Gruppiere Ist pro TOURNR in (lat, lon) Koordinatenpaare
ist_groups = {}
for tournr, g in ist.groupby('TOURNR'):
    coords = list(zip(g['lat'].astype(float).tolist(), g['lon'].astype(float).tolist()))
    ist_groups[tournr] = coords

# %%
ist.head()
# Out:
#   Fahrer PIN           Fahrername Formularnummer Richtung Geschwindigkeit  \
# 0     8317.0     Hesse, Sven-Erik           1651      114               2
# 1     8317.0     Hesse, Sven-Erik           1651        0               0
# 2     8311.0  Szmajdewicz, Marcin           1650        0               0
# 3     8311.0  Szmajdewicz, Marcin           1650        0               0
# 4     8311.0  Szmajdewicz, Marcin           1650        0               0
#
#      KM-Stand Gesamtverbrauch Tankfüllstand Breitengrad Längengrad  \
# 0   339694.28             0.0           0.0    53,53443    9,97895
# 1   339706.56             0.0           0.0    53,53432    9,98122
# 2   183989.36         52329.5          70.0    53,52345    9,98601
# 3  184074.345         52353.5          64.0    52,98145    9,59825
# 4   184160.38         52376.0          60.0    53,52343     9,9859
#
#                                             Position  \
# 0     DE - 20457 Hamburg (Hamburg-Mitte), Vogelreth
# 1  DE - 20457 Hamburg (Hamburg-Mitte), Werftstraße 5
# 2  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 3    DE - 27374 Visselhövede, Rudolf-Diesel-Straße 1
# 4  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
#
#                        Fahrzeug       DATUM KENNZ_CLEAN   TOURNR  \
# 0   Plö-TS856 - Fahrzeugdetails  2026-03-02   Plo-TS856  H/42374
# 1   Plö-TS856 - Fahrzeugdetails  2026-03-02   Plo-TS856  H/42374
# 2  OD-TS 8050 - Fahrzeugdetails  2026-03-02   OD-TS8050  H/42375
# 3  OD-TS 8050 - Fahrzeugdetails  2026-03-02   OD-TS8050  H/42375
# 4  OD-TS 8050 - Fahrzeugdetails  2026-03-02   OD-TS8050  H/42375
#
#                Abfahrt             Ankunft       lat      lon
# 0  2026-03-02 09:26:01                 NaT  53.53443  9.97895
# 1  2026-03-02 16:24:25                 NaT  53.53432  9.98122
# 2  2026-03-02 05:50:17 2026-03-02 05:50:16  53.52345  9.98601
# 3                  NaN 2026-03-02 08:17:09  52.98145  9.59825
# 4                  NaN 2026-03-02 11:21:25  53.52343  9.98590

# %% [markdown]
# ### Finde Touren, die in Reihenfolge und Stoppabdeckung übereinstimmen
# Touren werden in "matchedsoll.csv","matchedist.csv","mergedmatchedtours.csv" gespeichert, wenn man möchte (Zeilen zurzeit auskommentiert). Anhand dieser Ergebnisse wurde festgestellt, dass viele der Touren, die übereinstimmen nur 1 oder 2 Stopps besitzen und sich deshalb nicht für weitere Analysen eignen.

# %%
def tour_sequence_matches_strict(
    istseq,
    sollseq,
    radiusm=MATCH_RADIUS_M,
    min_match_ratio=0.8,
    require_unique_soll=False,
    allow_skips=True,
):
    """
    Prüft, ob Ist dieselbe Stop-Reihenfolge wie Soll abfährt.

    - Pro Ist-Punkt wird der nächste Soll-Punkt innerhalb radius gesucht.
    - Die Folge der gematchten Soll-Indizes muss streng aufsteigend sein
      (keine Wiederholung desselben Soll-Stopps).
    - Mindestanteil gematchter Soll-Stopps über min_match_ratio.
    """

    # liste für jeden Ist-Punkt mit: welcher Ist-Punkt das ist, welcher Soll-Index dazu passt und wie groß die Distanz war
    matched = []

    # schleife über alle ist-punkte in reihenfolge
    for i, (ilat, ilon) in enumerate(istseq):
        best_idx = None
        best_dist = float("inf")

        # schleife über alle soll-punkte
        # für jeden punkt wird distanz zum ist-punkt berechnet
        for j, (slat, slon) in enumerate(sollseq):
            d = haversine(ilat, ilon, slat, slon)
            # wenn neu berechnete distanz kleiner als bisher beste distanz -> neuer soll stopp als bester kandidat
            if d < best_dist:
                best_dist = d
                best_idx = j
        # ist bester soll-stop nah genug -> match
        if best_dist <= radiusm:
            matched.append({
                "ist_idx": i,
                "soll_idx": best_idx,
                "dist_m": best_dist
            })
        else:
            matched.append({
                "ist_idx": i,
                "soll_idx": None,
                "dist_m": None
            })

    # filtern alle ungültigen matches heraus 
    # es bleiben nur ist-punkte übrig, die wirklich in dr Nähe eines Soll-Stopps lagen
    valid = [m for m in matched if m["soll_idx"] is not None]
    matched_indices = [m["soll_idx"] for m in valid]

    if len(valid) == 0:
        return False, {
            "matched": matched,
            "matched_count": 0,
            "soll_count": len(sollseq),
            "ist_count": len(istseq),
            "coverage_ratio": 0.0,
            "strictly_increasing": False,
            "unique_soll_count": 0,
            "matched_indices": [],
            "reason": "kein Punkt innerhalb Radius"
        }
    # prüfen ob die Reihenfolge aufsteigend ist
    strictly_increasing = all(
        a < b for a, b in zip(matched_indices, matched_indices[1:])
    )

    unique_soll_count = len(set(matched_indices))
    coverage_ratio = unique_soll_count / len(sollseq) if len(sollseq) else 0.0

    if require_unique_soll:
        unique_ok = len(matched_indices) == unique_soll_count
    else:
        unique_ok = True

    if allow_skips:
        coverage_ok = coverage_ratio >= min_match_ratio
    else:
        coverage_ok = unique_soll_count == len(sollseq)

    matches = strictly_increasing and unique_ok and coverage_ok

    return matches, {
        "matched": matched,
        "matched_count": len(valid),
        "soll_count": len(sollseq),
        "ist_count": len(istseq),
        "coverage_ratio": coverage_ratio,
        "strictly_increasing": strictly_increasing,
        "unique_soll_count": unique_soll_count,
        "matched_indices": matched_indices,
        "reason": None if matches else {
            "strictly_increasing": strictly_increasing,
            "unique_ok": unique_ok,
            "coverage_ok": coverage_ok
        }
    }


# Prüfe alle TOURNR, die in beiden Sets vorkommen 
commontournr = set(soll_groups.keys()).intersection(set(ist_groups.keys()))
matchingtournr = []
matchdetails = {}

for t in sorted(commontournr):
    istseq = ist_groups[t]
    sollseq = soll_groups[t]

    matches, details = tour_sequence_matches_strict(
        istseq,
        sollseq,
        radiusm=MATCH_RADIUS_M,
        min_match_ratio=0.8,
        require_unique_soll=False,
        allow_skips=True
    )

    matchdetails[t] = details

    if matches:
        matchingtournr.append(t)


# Join der DataFrames für gematchte TOURNR 
matchedsoll = soll[soll["TOURNR"].isin(matchingtournr)].copy()
matchedist = ist[ist['TOURNR'].isin(matchingtournr)].copy()

# Optional: nummeriere Stop-Positionen innerhalb jeder Tour
matchedsoll["sollstopidx"] = matchedsoll.groupby("TOURNR").cumcount() + 1
matchedist["iststopidx"] = matchedist.groupby('TOURNR').cumcount() + 1

# Einfacher Join auf TOURNR
merged = pd.merge(
    matchedist,
    matchedsoll,
    left_on='TOURNR',
    right_on="TOURNR",
    suffixes=("_ist", "_soll")
)

# Speichere Ergebnisse
pd.DataFrame({"matchingtournr": list(matchingtournr)}).to_csv("matchingtournr.csv", index=False)
# matchedsoll.to_csv("matchedsoll.csv", index=False)
# matchedist.to_csv("matchedist.csv", index=False)
# merged.to_csv("mergedmatchedtours.csv", index=False)

# Speichere Detail-Report
with open("matchdetails.json", "w", encoding="utf-8") as f:
    json.dump(
        {
            "MATCH_RADIUS_M": MATCH_RADIUS_M,
            "matchingtournr": matchingtournr,
            "details": matchdetails
        },
        f,
        ensure_ascii=False,
        indent=2
    )

print(
    f"Fertig. Gefundene gematchte Touren: {len(matchingtournr)}. "
)
# Out:
# Fertig. Gefundene gematchte Touren: 14.

# %% [markdown]
# ### Touren, die matchen

# %%
matchingtournr
# Out:
# ['H/42406',
#  'H/42446',
#  'H/42473',
#  'H/42483',
#  'H/42499',
#  'H/42560',
#  'H/42572',
#  'H/42576',
#  'H/42579',
#  'H/42589',
#  'H/42605',
#  'H/42620',
#  'H/42675',
#  'H/42682']

# %% [markdown]
# ### Plotten des Ergebnisses

# %%
# Alle Touren in ist
all_ist_tours = ist[ist['TOURNR'].notna()]['TOURNR'].dropna().astype(str).unique()

# Gematchte Touren aus deiner bestehenden Reihenfolge-Logik
matched_tours = pd.Series(matchingtournr).astype(str).unique()

# Zählen
matched_count = len(set(all_ist_tours).intersection(set(matched_tours)))
unmatched_count = len(set(all_ist_tours)) - matched_count

pie_df = pd.DataFrame({
    "Status": ["Matcht nicht", "Matcht in Tourreihenfolge"],
    "Anzahl": [unmatched_count, matched_count]
})

fig = px.pie(
    pie_df,
    names="Status",
    values="Anzahl",
    color="Status",
    color_discrete_map={
        "Matcht nicht": "#ff0000",
        "Matcht in Tourreihenfolge": "#00498b"
    },
    title="Anteil der Ist-Touren, die in der Tourreihenfolge matchen (EMR)",
    hole=0.35,
    width=600,
    height=500
)

fig.update_traces(
    textinfo="percent+label",
    sort=False
)

fig.show()

# %% [markdown]
# ### Sauberer Pair-Merge auf Basis der echten Matches
# * bauen aus `matchdetails[t]["matched"]` eine echte Match-Tabelle und nehmen dann die laufenden Indizes ist_idx und soll_idx je Tour und merged genau auf diese Paarung statt nur auf TOURNR
# * daraus dann pro Match eine Zeile mit Distanz, Ist-Zeit, Soll-Zeit und daraus delay_min
# * Matching-Logik kann mehrere Ist-Punkte demselben Soll-Stopp zuordnen, weil pro Ist-Punkt der nächste Soll-Punkt gesucht wird -> paired_best reduziert das auf genau einen besten Kandidaten pro TOURNR + soll_idx, nämlich den mit der kleinsten Distanz, was für Stop-basierte Delay-Auswertungen meist die sauberste Variante ist
# * diese Touren wurden ursprünglich dafür verwendet, um genauere Analysen der matching Touren zu generieren, aber nachdem wir festgestellt haben, dass sie oft nur 1 oder 2 Stopps pro Tour aufgewiesen haben, wurde dieses Ergebnis nicht weiter verfolgt

# %%
pair_rows = []

for tournr in matchingtournr:
    details = matchdetails[tournr]

    for m in details["matched"]:
        if m["soll_idx"] is None:
            continue

        pair_rows.append({
            "TOURNR": tournr,
            "ist_idx": m["ist_idx"],
            "soll_idx": m["soll_idx"],
            "dist_m": m["dist_m"]
        })

pairs = pd.DataFrame(pair_rows)

# Falls keine Paare gefunden wurden
if pairs.empty:
    raise ValueError("Keine gültigen Match-Paare in matchdetails gefunden.")

# Eindeutige laufende Indizes je Tour in Originaldaten

matchedist = ist[ist['TOURNR'].isin(matchingtournr)].copy()
matchedsoll = soll[soll["TOURNR"].isin(matchingtournr)].copy()

matchedist = matchedist.sort_values(['TOURNR', 'Ankunft']).reset_index(drop=True)
matchedsoll = matchedsoll.sort_values(["TOURNR", "ANKUNFT"]).reset_index(drop=True)

matchedist["ist_idx"] = matchedist.groupby('TOURNR').cumcount()
matchedsoll["soll_idx"] = matchedsoll.groupby("TOURNR").cumcount()

# Nur benötigte Spalten für Ist / Soll vorbereiten

ist_cols_keep = ['TOURNR', "ist_idx", 'Ankunft', "lat", "lon"]
for c in ["Abfahrt", "Ankunft", "Position", "Fahrzeug", "KENNZCLEAN", "DATUM"]:
    if c in matchedist.columns and c not in ist_cols_keep:
        ist_cols_keep.append(c)

soll_cols_keep = ["TOURNR", "soll_idx", "ANKUNFT", "ABFAHRT", "GEOY", "GEOX"]
for c in ["STRASSE", "ORT", "PLZ", "LKWKENNZ", "FAHRERNAME", "DATUM"]:
    if c in matchedsoll.columns and c not in soll_cols_keep:
        soll_cols_keep.append(c)

ist_for_merge = matchedist[ist_cols_keep].copy()
soll_for_merge = matchedsoll[soll_cols_keep].copy()

# Umbenennen für Klarheit
ist_for_merge = ist_for_merge.rename(columns={
    'TOURNR': "TOURNR",
    'Ankunft': "IstZeit",
    "Ankunft": "IstAnkunft",
    "Abfahrt": "IstAbfahrt",
    "Position": "IstPosition",
    "Fahrzeug": "IstFahrzeug",
    "DATUM": "DATUMist"
})

soll_for_merge = soll_for_merge.rename(columns={
    "ANKUNFT": "SollAnkunft",
    "ABFAHRT": "SollAbfahrt",
    "GEOY": "SollLat",
    "GEOX": "SollLon",
    "STRASSE": "SollStrasse",
    "ORT": "SollOrt",
    "PLZ": "SollPLZ",
    "DATUM": "DATUMsoll"
})

# Echter Merge über TOURNR + Indexpaar

paired = pairs.merge(
    ist_for_merge,
    on=["TOURNR", "ist_idx"],
    how="left"
).merge(
    soll_for_merge,
    on=["TOURNR", "soll_idx"],
    how="left"
)

# Delay berechnen
# Falls IstZeit nicht brauchbar ist, nimm bevorzugt IstAnkunft, sonst IstAbfahrt

if "IstAnkunft" in paired.columns:
    paired["IstZeitFinal"] = pd.to_datetime(paired["IstAnkunft"], errors="coerce")
else:
    paired["IstZeitFinal"] = pd.NaT

if "IstAbfahrt" in paired.columns:
    ist_abfahrt_dt = pd.to_datetime(paired["IstAbfahrt"], errors="coerce")
    paired["IstZeitFinal"] = paired["IstZeitFinal"].fillna(ist_abfahrt_dt)

paired["SollZeitFinal"] = pd.to_datetime(paired["SollAnkunft"], errors="coerce")

paired["delay_min"] = (
    (paired["IstZeitFinal"] - paired["SollZeitFinal"]).dt.total_seconds() / 60.0
)

# nur beste/saubere Paare behalten
# Falls mehrere Ist-Punkte auf denselben Soll-Stopp zeigen,
# behalte den mit der kleinsten Distanz

paired_best = (
    paired.sort_values(["TOURNR", "soll_idx", "dist_m"])
          .drop_duplicates(subset=["TOURNR", "soll_idx"], keep="first")
          .sort_values(["TOURNR", "soll_idx"])
          .reset_index(drop=True)
)

# Exporte

# pairs.to_csv("match_pairs_raw.csv", index=False)
# paired.to_csv("matched_pairs_full.csv", index=False)
# paired_best.to_csv("matched_pairs_best.csv", index=False)

# Optional: Delay-Zusammenfassung pro Tour
tour_delay_summary = (
    paired_best.groupby("TOURNR", dropna=False)
    .agg(
        n_pairs=("soll_idx", "count"),
        avg_delay_min=("delay_min", "mean"),
        median_delay_min=("delay_min", "median"),
        max_delay_min=("delay_min", "max"),
        min_delay_min=("delay_min", "min")
    )
    .reset_index()
)

# tour_delay_summary.to_csv("tour_delay_summary.csv", index=False)

print(
    f"Fertig. {len(pairs)} Roh-Paare, "
    f"{len(paired_best)} eindeutige beste Paare gespeichert."
)
# Out:
# Fertig. 58 Roh-Paare, 58 eindeutige beste Paare gespeichert.

# %% [markdown]
# Unerwartetes Ergebnis: Nur 14 Touren mit Stopps in der richtigen Reihenfolge
# ## Berechnung der Anzahl der Touren, die alle Stopps abfahren
# * zuerst Anzahl der Touren bestimmt, die mindestens 80% der Stopps abfahren -> 90
# * bei 100% waren es aber auch 90

# %%
# Ist-Touren finden, die mindestens ...% der Soll-Stopps überhaupt anfahren
MIN_STOP_COVERAGE = 1

def tour_stops_covered_any_order(istseq, sollseq, radiusm=MATCH_RADIUS_M, min_coverage=MIN_STOP_COVERAGE):
    """
    Prüft, ob eine Ist-Tour mindestens min_coverage der Soll-Stopps räumlich erreicht,
    unabhängig von der Reihenfolge.

    Logik:
    - Für jeden Soll-Stopp wird geprüft, ob es mindestens einen Ist-Punkt innerhalb radiusm gibt.
    - Gezählt werden eindeutige besuchte Soll-Stopps.
    """
    covered_soll_idx = []
    details = []

    for j, (slat, slon) in enumerate(sollseq):
        best_ist_idx = None
        best_dist = float("inf")

        for i, (ilat, ilon) in enumerate(istseq):
            d = haversine(ilat, ilon, slat, slon)
            if d < best_dist:
                best_dist = d
                best_ist_idx = i

        is_covered = best_dist <= radiusm

        details.append({
            "sollidx": j,
            "best_ist_idx": best_ist_idx,
            "best_dist_m": best_dist,
            "covered": is_covered
        })

        if is_covered:
            covered_soll_idx.append(j)

    covered_count = len(covered_soll_idx)
    soll_count = len(sollseq)
    coverage_ratio = covered_count / soll_count if soll_count else 0.0
    matches = coverage_ratio >= min_coverage

    return matches, {
        "covered_soll_idx": covered_soll_idx,
        "covered_count": covered_count,
        "soll_count": soll_count,
        "coverage_ratio": coverage_ratio,
        "radius_m": radiusm,
        "min_coverage": min_coverage,
        "details": details
    }


# Nur Touren prüfen, die in Soll und Ist vorkommen
common_tournr = set(soll_groups.keys()).intersection(set(ist_groups.keys()))

covered_tournr = []
covered_details = {}

for t in sorted(common_tournr):
    istseq = ist_groups[t]
    sollseq = soll_groups[t]

    ok, details = tour_stops_covered_any_order(
        istseq,
        sollseq,
        radiusm=MATCH_RADIUS_M,
        min_coverage=0.8
    )

    covered_details[t] = details

    if ok:
        covered_tournr.append(t)

# Übersichtstabelle
covered_summary = pd.DataFrame([
    {
        "TOURNR": t,
        "covered_count": covered_details[t]["covered_count"],
        "soll_count": covered_details[t]["soll_count"],
        "coverage_ratio": covered_details[t]["coverage_ratio"]
    }
    for t in covered_tournr
]).sort_values(["coverage_ratio", "TOURNR"], ascending=[False, True]).reset_index(drop=True)

# Nur die Ist-Zeilen dieser Touren
ist_touren_mit_mind_80_prozent_stopps = ist[ist['TOURNR'].isin(covered_tournr)].copy()

# %%
ist_touren_mit_mind_80_prozent_stopps.TOURNR.nunique()
# Out:
# 90

# %% [markdown]
# ### 90 Touren in Ist-Daten der EMR Daten decken 80% (und 100%) der Stopps von den Soll-Daten ab
# ### Plotten des Ergebnisses

# %%
# Touren, die alle Soll-Stopps abdecken

full_match_tours = covered_summary.loc[
    covered_summary["coverage_ratio"] == 1.0, "TOURNR"
].astype(str).unique()

# Alle IST-Touren
all_ist_tours = ist[ist['TOURNR'].notna()]['TOURNR'].astype(str).unique()

# Zählen
full_match_count = len(set(all_ist_tours).intersection(set(full_match_tours)))
not_full_match_count = len(set(all_ist_tours)) - full_match_count

pie_df = pd.DataFrame({
    "Status": ["Matcht alle Stopps", "Matcht nicht alle Stopps"],
    "Anzahl": [full_match_count, not_full_match_count]
})

fig = px.pie(
    pie_df,
    names="Status",
    values="Anzahl",
    color="Status",
    color_discrete_map={
        "Matcht nicht alle Stopps": "#ff0000",
        "Matcht alle Stopps": "#00498b"
    },
    title="Anteil der Ist-Touren mit vollständiger Stopp-Abdeckung (EMR)",
    hole=0.35,
    width=700,
    height=700
)

fig.update_traces(
    textinfo="percent+label",
    sort=False
)

fig.show()

# %% [markdown]
# ## Stoppabdeckung pro Fahrer

# %%
# Blaue Balken: Touren mit >= 80 % Stopp-Abdeckung
df_blue = ist_touren_mit_mind_80_prozent_stopps.copy()

fahrer_col_blue = next(c for c in ["FAHRERNAME", "Fahrername", "fahrername"] if c in df_blue.columns)
tour_col_blue = next(c for c in ["TOURNR", "Tournummer", "tournr"] if c in df_blue.columns)

blue_counts = (
    df_blue[[fahrer_col_blue, tour_col_blue]]
    .drop_duplicates()
    .groupby(fahrer_col_blue, as_index=False)
    .agg(anzahl_touren_80=(tour_col_blue, "nunique"))
)

# Graue Balken: alle Touren insgesamt aus IST
df_all = ist.copy()

fahrer_col_all = next(c for c in ["FAHRERNAME", "Fahrername", "fahrername"] if c in df_all.columns)
tour_col_all = next(c for c in ["TOURNR", "Tournummer", "tournr"] if c in df_all.columns)

all_counts = (
    df_all[[fahrer_col_all, tour_col_all]]
    .drop_duplicates()
    .groupby(fahrer_col_all, as_index=False)
    .agg(anzahl_touren_gesamt=(tour_col_all, "nunique"))
)

# Zusammenführen
driver_counts = (
    all_counts.merge(
        blue_counts,
        left_on=fahrer_col_all,
        right_on=fahrer_col_blue,
        how="left"
    )
    .fillna({"anzahl_touren_80": 0})
)

# Einheitlichen Fahrernamen-Spaltennamen setzen
driver_counts = driver_counts.rename(columns={fahrer_col_all: "Fahrer"})
if fahrer_col_blue in driver_counts.columns and fahrer_col_blue != fahrer_col_all:
    driver_counts = driver_counts.drop(columns=[fahrer_col_blue])

driver_counts["anzahl_touren_80"] = driver_counts["anzahl_touren_80"].astype(int)

# Sortierung nach den blauen Balken
driver_counts = driver_counts.sort_values(
    ["anzahl_touren_80", "anzahl_touren_gesamt"],
    ascending=False
).reset_index(drop=True)

fig = go.Figure()

# Grauer Hintergrundbalken
fig.add_trace(go.Bar(
    x=driver_counts["anzahl_touren_gesamt"],
    y=driver_counts["Fahrer"],
    orientation="h",
    name="Alle Touren",
    marker_color="lightgray",
    text=driver_counts["anzahl_touren_gesamt"],
    textposition="outside",
    cliponaxis=False
))

# Blauer Vordergrundbalken
fig.add_trace(go.Bar(
    x=driver_counts["anzahl_touren_80"],
    y=driver_counts["Fahrer"],
    orientation="h",
    name="Touren mit >= 80 % Stopp-Abdeckung",
    marker_color="#00498b",
    text=driver_counts["anzahl_touren_80"],
    textposition="inside"
))

fig.update_layout(
    title="Fahrer: Touren mit kompletter Stopp-Abdeckung vs. alle gefahrenen Touren",
    xaxis_title="Anzahl Touren",
    yaxis_title="Fahrer",
    yaxis=dict(autorange="reversed"),
    barmode="overlay",
    bargap=0.25,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0
    )
)

fig.show()

# %% [markdown]
# ## Gleiche Analyse mit PRC Daten
# ## Data Cleaning in PRC Daten

# %%
prc = pd.read_csv('istdaten_prc_clean.csv')

# %% [markdown]
# ## Kennzeichen normalisieren
# Kennzeichen sind in Soll-Daten und PRC-Daten nicht in derselben Form angegeben, wenn es sich um dasselbe Kennzeichen handelt

# %%
prc.LKW_KENNZ.unique()
# Out:
# array(['PLO-TS-859', 'PLO-TS-856', 'OD-TS-8050', 'OD-TS-8046',
#        'PLO-TS-853', 'OD-TS-8044', 'OD-TS-8048', 'OD-TS-8041',
#        'PI-EN-444', 'PI-EN-900', 'WL-PL-431', 'PLO-TS-857'], dtype=object)

# %%
soll.LKW_KENNZ.unique()
# Out:
# array(['Plo-TS856', 'OD-TS8050', 'Plo-TS859', 'OD-TS8041', 'OD-TS8044',
#        'Plö-TS853', 'OD-TS8046', 'OD-TS8048', 'PI-EN 444', 'RW435',
#        'PI-EN 900', 'WL-PL431', 'Leihwagen', 'Plö-TS857'], dtype=object)

# %%
import unicodedata

# Funktion zum Normalisieren von Kennzeichen (entfernt "-", Leerzeichen, normalisiert Case und Umlaute)
def normalise_kennzeichen(kz):
    if pd.isna(kz):
        return kz
    kz_str = str(kz)
    # Entferne "-" und Leerzeichen
    kz_normalized = kz_str.replace("-", "").replace(" ", "")
    # Normalisiere zu lowercase für Vergleich
    kz_normalized = kz_normalized.lower()
    # Umlaute normalisieren (ö -> o)
    kz_normalized = unicodedata.normalize('NFKD', kz_normalized)
    kz_normalized = ''.join(c for c in kz_normalized if not unicodedata.combining(c))
    return kz_normalized.lower()

# Erstelle Mapping von normalisiert -> Original aus soll
soll_kennzeichen = soll['LKW_KENNZ'].unique()
mapping = {}
for kz in soll_kennzeichen:
    normalised = normalise_kennzeichen(kz)
    mapping[normalised] = kz  # Original aus soll speichern

# Ersetze Kennzeichen in prc, wenn sie im Mapping gefunden werden
def replace_kennzeichen(kz):
    normalised = normalise_kennzeichen(kz)
    return mapping.get(normalised, kz)  # Rückgabe Original aus soll, wenn Match

prc['LKW_KENNZ'] = prc['LKW_KENNZ'].apply(replace_kennzeichen)

# %%
prc.LKW_KENNZ.unique()
# Out:
# array(['Plo-TS859', 'Plo-TS856', 'OD-TS8050', 'OD-TS8046', 'Plö-TS853',
#        'OD-TS8044', 'OD-TS8048', 'OD-TS8041', 'PI-EN 444', 'PI-EN 900',
#        'WL-PL431', 'Plö-TS857'], dtype=object)

# %%
soll.LKW_KENNZ.unique()
# Out:
# array(['Plo-TS856', 'OD-TS8050', 'Plo-TS859', 'OD-TS8041', 'OD-TS8044',
#        'Plö-TS853', 'OD-TS8046', 'OD-TS8048', 'PI-EN 444', 'RW435',
#        'PI-EN 900', 'WL-PL431', 'Leihwagen', 'Plö-TS857'], dtype=object)

# %% [markdown]
# ## Tournummern in PRC Daten zuordnen
# * neue Spalte `TourID` erstellen mit ergänzten Tournummern aus `soll`
# * ursprüngliche Spalte `TOURNR` bleibt

# %%
# Datum aus dem Zeitstempel in prc ableiten

prc['DATUM'] = pd.to_datetime(prc['Zeitstempel_Fahrzeug'], errors='coerce').dt.strftime('%Y-%m-%d')

# Eindeutiges Mapping erstellen (eine Tournr pro Kennz+Datum)
if not {'LKW_KENNZ', 'DATUM', 'TOURNR'}.issubset(soll.columns):
    raise KeyError(f"Fehlende Spalten in soll: {set(['LKW_KENNZ', 'DATUM', 'TOURNR']) - set(soll.columns)}")

if not {'LKW_KENNZ', 'DATUM'}.issubset(prc.columns):
    raise KeyError(f"Fehlende Spalten in prc: {set(['LKW_KENNZ', 'DATUM']) - set(prc.columns)}")

tour_mapping = soll.groupby(['LKW_KENNZ', 'DATUM'])['TOURNR'].apply(lambda x: x.iloc[0]).reset_index()
tour_mapping.columns = ['LKW_KENNZ', 'DATUM', 'TOURNR']

# Merge auf prc
prc = prc.merge(tour_mapping, on=['LKW_KENNZ', 'DATUM'], how='left')

# TourID nur ergänzen, wenn sie noch fehlt
if 'TourID' in prc.columns:
    prc['TourID'] = prc['TourID'].fillna(prc['TOURNR'])
else:
    prc['TourID'] = prc['TOURNR']

print(prc['TourID'].isna().sum(), "Zeilen in prc ohne TourID")
print(prc['TourID'].notna().sum(), "Zeilen in prc mit TourID")
# Out:
# 403 Zeilen in prc ohne TourID
# 29027 Zeilen in prc mit TourID

# %% [markdown]
# ## Entfernen der Zeilen ohne Tournummer

# %%
prc = prc[prc.TourID.notna()]

# %%
prc
# Out:
#        Unnamed: 0     msg_typ  PositionsID  Longitude  Latitude  \
# 0              14  Tourstatus  16053922721    9.98546  53.52336
# 1              22    Position  16054978711    9.98546  53.52335
# 2             149    Position  16056142197    9.98547  53.52335
# 3             196    Position  16056260113    9.98639  53.52345
# 4             197    Position  16056260217    9.98648  53.52344
# ...           ...         ...          ...        ...       ...
# 29022       29381    Position  16264464604    9.78478  53.47492
# 29023       29392    Position  16264512127    9.78143  53.49959
# 29024       29403    Position  16264561912    9.80004  53.52127
# 29025       29410    Position  16264614488    9.83213  53.51558
# 29026       29427    Position  16264666908    9.89029  53.51766
#
#        Geschwindigkeit  KMStand      Zeitstempel_GPS Zeitstempel_Fahrzeug  \
# 0                    0   339687  2026-03-01 14:33:05  2026-03-01 14:33:05
# 1                    0   339687  2026-03-01 23:59:59  2026-03-02 00:00:00
# 2                    0   339687  2026-03-02 05:59:59  2026-03-02 06:00:00
# 3                   20   339687  2026-03-02 06:16:45  2026-03-02 06:16:45
# 4                   20   339687  2026-03-02 06:16:46  2026-03-02 06:16:46
# ...                ...      ...                  ...                  ...
# 29022               19   464874  2026-03-31 12:57:27  2026-03-31 12:57:27
# 29023               44   464878  2026-03-31 13:02:45  2026-03-31 13:02:45
# 29024               30   464881  2026-03-31 13:08:22  2026-03-31 13:08:22
# 29025               58   464885  2026-03-31 13:14:02  2026-03-31 13:14:02
# 29026               39   464890  2026-03-31 13:20:10  2026-03-31 13:20:10
#
#         Zeitstempel_Server  LKW_KENNZ  Status   TourID StationID SendposID  \
# 0      2026-03-01 14:33:15  Plo-TS856    22.0  H/42374       NaN       NaN
# 1      2026-03-02 00:00:47  Plo-TS856     NaN  H/42374       NaN       NaN
# 2      2026-03-02 06:00:49  Plo-TS856     NaN  H/42374       NaN       NaN
# 3      2026-03-02 06:17:04  Plo-TS856     NaN  H/42374       NaN       NaN
# 4      2026-03-02 06:17:04  Plo-TS856     NaN  H/42374       NaN       NaN
# ...                    ...        ...     ...      ...       ...       ...
# 29022  2026-03-31 13:01:33  OD-TS8046     NaN  H/42666       NaN       NaN
# 29023  2026-03-31 13:06:38  OD-TS8046     NaN  H/42666       NaN       NaN
# 29024  2026-03-31 13:12:17  OD-TS8046     NaN  H/42666       NaN       NaN
# 29025  2026-03-31 13:17:55  OD-TS8046     NaN  H/42666       NaN       NaN
# 29026  2026-03-31 13:24:03  OD-TS8046     NaN  H/42666       NaN       NaN
#
#        Ereignis_Typ       DATUM   TOURNR       lat      lon
# 0               NaN  2026-03-01      NaN  53.52336  9.98546
# 1               NaN  2026-03-02  H/42374  53.52335  9.98546
# 2               NaN  2026-03-02  H/42374  53.52335  9.98547
# 3               NaN  2026-03-02  H/42374  53.52345  9.98639
# 4               NaN  2026-03-02  H/42374  53.52344  9.98648
# ...             ...         ...      ...       ...      ...
# 29022           NaN  2026-03-31  H/42666  53.47492  9.78478
# 29023           NaN  2026-03-31  H/42666  53.49959  9.78143
# 29024           NaN  2026-03-31  H/42666  53.52127  9.80004
# 29025           NaN  2026-03-31  H/42666  53.51558  9.83213
# 29026           NaN  2026-03-31  H/42666  53.51766  9.89029
#
# [29027 rows x 20 columns]

# %%
# prc.to_csv('prc_mit_tournummer.csv')

# %%
prc = pd.read_csv('prc_mit_tournummer.csv')

# %% [markdown]
# ## In welchen Touren sind alle Stopps in der gleichen Reihenfolge zwischen Soll- und Ist-Daten?

# %%
# PRC-Touren prüfen: Sind alle Soll-Stopps abgefahren worden?
PRC_MATCH_RADIUS_M = 300

prc_tour_col = 'TourID' if 'TourID' in prc.columns else 'TOURNR'

if 'Longitude' not in prc.columns or 'Latitude' not in prc.columns:
    raise KeyError("Fehlende Koordinatenspalten in prc. Erwartet 'Longitude' und 'Latitude'.")

prc['lat'] = prc['Latitude'].apply(parse_decimal_coord)
prc['lon'] = prc['Longitude'].apply(parse_decimal_coord)
prc = prc[prc[prc_tour_col].notna()].copy()
prc = prc.sort_values([prc_tour_col, 'Zeitstempel_Fahrzeug']).reset_index(drop=True)

prc_groups = {}
for tournr, g in prc.groupby(prc_tour_col):
    coords = list(zip(g['lat'].astype(float).tolist(), g['lon'].astype(float).tolist()))
    prc_groups[tournr] = coords

common_prc_tournr = set(soll_groups.keys()).intersection(set(prc_groups.keys()))

prc_covered_tournr = []
prc_covered_details = {}
for t in sorted(common_prc_tournr):
    prcseq = prc_groups[t]
    sollseq = soll_groups[t]

    ok, details = tour_stops_covered_any_order(
        prcseq,
        sollseq,
        radiusm=PRC_MATCH_RADIUS_M,
        min_coverage=1.0
    )

    prc_covered_details[t] = details
    if ok:
        prc_covered_tournr.append(t)

prc_covered_summary = pd.DataFrame([
    {
        'TOURNR': t,
        'covered_count': prc_covered_details[t]['covered_count'],
        'soll_count': prc_covered_details[t]['soll_count'],
        'coverage_ratio': prc_covered_details[t]['coverage_ratio']
    }
    for t in prc_covered_tournr
]).sort_values(['coverage_ratio', 'TOURNR'], ascending=[False, True]).reset_index(drop=True)

prc_touren_mit_kompletter_stopabdeckung = prc[prc[prc_tour_col].isin(prc_covered_tournr)].copy()

print('Gemeinsame Touren zwischen Soll und PRC:', len(common_prc_tournr))
print('PRC-Touren mit kompletter Soll-Stopp-Abdeckung:', len(prc_covered_tournr))
print('PRC-Zeilen dieser Touren:', len(prc_touren_mit_kompletter_stopabdeckung))
prc_covered_summary.head()
# Out:
# Gemeinsame Touren zwischen Soll und PRC: 202
# PRC-Touren mit kompletter Soll-Stopp-Abdeckung: 92
# PRC-Zeilen dieser Touren: 12727
#     TOURNR  covered_count  soll_count  coverage_ratio
# 0  H/42378              5           5             1.0
# 1  H/42379              8           8             1.0
# 2  H/42383             12          12             1.0
# 3  H/42392              2           2             1.0
# 4  H/42400             12          12             1.0

# %% [markdown]
# ## Touren, die alle Stopps von `soll` abgefahren sind

# %%
PRCMATCH_RADIUS_M = 300

prctourcol = 'TourID' if 'TourID' in prc.columns else 'TOURNR'
if 'Longitude' not in prc.columns or 'Latitude' not in prc.columns:
    raise KeyError('Fehlende Koordinatenspalten in prc. Erwartet Longitude und Latitude.')

prclat = prc['Latitude'].apply(parse_decimal_coord)
prclon = prc['Longitude'].apply(parse_decimal_coord)

prc = prc[prc[prctourcol].notna()].copy()
prc = prc.sort_values([prctourcol, 'Zeitstempel_Fahrzeug']).reset_index(drop=True)

prcgroups = {}
for tournr, g in prc.groupby(prctourcol):
    coords = list(zip(g['Latitude'].astype(float).tolist(), g['Longitude'].astype(float).tolist()))
    prcgroups[tournr] = coords

commonprctournr = set(soll_groups.keys()).intersection(set(prcgroups.keys()))

prccoveredtournr = []
prccovereddetails = {}

for t in sorted(commonprctournr):
    prcseq = prcgroups[t]
    sollseq = soll_groups[t]
    ok, details = tour_stops_covered_any_order(
        prcseq, sollseq,
        radiusm=PRCMATCH_RADIUS_M,
        min_coverage=1.0,
    )
    prccovereddetails[t] = details
    if ok:
        prccoveredtournr.append(t)

prccovered_summary = pd.DataFrame([
    {
        'TOURNR': t,
        'covered_count': prccovereddetails[t]['covered_count'],
        'soll_count': prccovereddetails[t]['soll_count'],
        'coverage_ratio': prccovereddetails[t]['coverage_ratio'],
    }
    for t in prccoveredtournr
]).sort_values(['coverage_ratio', 'TOURNR'], ascending=[False, True]).reset_index(drop=True)

prc_komplette_stopabdeckung = prc[prc[prctourcol].isin(prccoveredtournr)].copy()

# %%
prc_komplette_stopabdeckung.TourID.nunique()
# Out:
# 92

# %% [markdown]
# ### Ergebnis: 92 in PRC Daten vs. 90 in Soll Daten in Tournummern

# %% [markdown]
# ## Tour Klassifikation und Routenähnlichkeits-Score
# * Der Code vergleicht für jede Tour die geplante Soll-Route mit der tatsächlich gefahrenen Ist-Route und ordnet dann anhand mehrerer Kriterien einen Abweichungstyp zu.
# * Betrachten nur Touren, die in Soll- und Ist-Daten beide vorkommen. So wird pro TOURNR bzw. Tour-ID ein Vergleich möglich.
# * Stopps als Punktfolgen aufbauen
# * Aus den Soll-Daten wird je Tour eine geordnete Liste von Stopps erstellt, aus den Ist-Daten eine geordnete Liste von GPS-Punkten. Damit wird die Route nicht als Text, sondern als Punktfolge verglichen.
# * Für jeden Ist-Punkt sucht der Code den nächstgelegenen Soll-Stopp. Nur wenn der Abstand kleiner als ein fester Radius ist, gilt der Punkt als Match. Dadurch wird verhindert, dass weit entfernte Punkte fälschlich als passend gezählt werden.
# * Die gefundenen Soll-Stopps werden in ihrer Trefferreihenfolge betrachtet. Wenn die Indexfolge nicht monoton aufsteigt, ist die Stopfreihenfolge verändert.
# * Der Code zählt, wie viele unterschiedliche Soll-Stopps überhaupt getroffen wurden. Daraus wird die Abdeckung berechnet:
# * Abdeckung = getroffene Soll-Stopps/alle Soll-Stopps
# * Zusätzlich vergleicht der Code die ungefähre Routenlänge von Soll und Ist sowie die Zeitdifferenzen aus den bereits gematchten Stopps. So erkennt er Umwege, Mehrkilometer und Verzögerungen.
#
# Entscheidungslogik:
# * Kein räumliches Match, wenn keine sinnvollen Treffer innerhalb des Radius gefunden wurden
# * Starke Abdeckungslücke, wenn nur sehr wenige Soll-Stopps erreicht wurden.
# * Teilabdeckung + Reihenfolgefehler, wenn nur ein Teil der Stopps erreicht wurde und die Reihenfolge zusätzlich falsch ist.
# * Ausgelassene Stopps, wenn Stopps fehlen, aber die Reihenfolge sonst passt.
# * Reihenfolge geändert, wenn alle Stopps da sind, aber in anderer Reihenfolge.
# * Viele Zusatzbewegungen, wenn deutlich mehr Bewegungen/GPS-Punkte vorkommen als erwartet.
#
# Alle Touren werden nach diesen Klassen eingeordnet:
# * Plannah: Die Tour verläuft weitgehend wie geplant. Die Soll-Stopps werden in richtiger Reihenfolge und mit guter räumlicher Übereinstimmung abgefahren, ohne nennenswerte Abweichungen bei Distanz oder Zeit.
# * Reihenfolge geändert: Die richtigen Stopps werden zwar angefahren, aber in einer anderen Reihenfolge als in der Soll-Tour. Die Route ist also inhaltlich ähnlich, aber die Sequenz der Stopps weicht ab.
# * Ausgelassene Stopps: Ein Teil der geplanten Stopps wurde nicht angefahren. Die Tour deckt also nur einen Teil der Soll-Route ab, die Reihenfolge kann dabei trotzdem noch teilweise stimmen.
# * Teilabdeckung + Reihenfolgefehler: Es werden nur einige der Soll-Stopps erreicht, und diese werden zusätzlich nicht in der vorgesehenen Reihenfolge angefahren. Das ist eine Kombination aus ausgelassenen Stopps und Sequenzfehlern.
# * Viele Zusatzbewegungen: Die Ist-Tour enthält deutlich mehr GPS-Punkte oder Bewegungen als durch die Soll-Tour erklärbar wären. Das kann auf Zwischenfahrten, zusätzliche nicht geplante Fahrbewegungen oder unruhige Routenführung hindeuten.
# * Kein räumliches Match: Es lässt sich kein Tourverlauf erkennen, der räumlich sinnvoll zu den geplanten Stopps passt. Weder die Stopps noch die Route liegen ausreichend nahe an der Soll-Tour.

# %%
def inversion_count(seq):
    seq = [x for x in seq if pd.notna(x)]
    inv = 0
    for i in range(len(seq)):
        for j in range(i + 1, len(seq)):
            if seq[i] > seq[j]:
                inv += 1
    return inv


# Any-order-Coverage aus vorhandener coveredsummary
coverage_map = {}
if "prc_covered_summary" in globals():
    tmp_cov = prc_covered_summary.copy()
    coverage_map = tmp_cov.set_index("TOURNR").to_dict("index")


all_tours = sorted(set(soll_groups.keys()).intersection(set(ist_groups.keys())))

rows = []

for t in all_tours:
    sollseq = soll_groups[t]
    istseq = ist_groups[t]

    n_soll = len(sollseq)
    n_ist = len(istseq)

    details = matchdetails.get(t, {})
    matched = details.get("matched", [])

    matched_indices = [m["sollidx"] for m in matched if m.get("sollidx") is not None]
    valid_distances = [m["distm"] for m in matched if m.get("distm") is not None]

    unique_soll_count = len(set(matched_indices))
    strict_coverage_ratio = unique_soll_count / n_soll if n_soll else 0.0
    strictly_increasing = all(a <= b for a, b in zip(matched_indices, matched_indices[1:])) if len(matched_indices) > 1 else True
    inv_count = inversion_count(matched_indices)

    cov_info = coverage_map.get(t, {})
    anyorder_coverage_ratio = cov_info.get("coverage_ratio", strict_coverage_ratio)
    covered_count = cov_info.get("covered_count", unique_soll_count)

    mean_match_dist = float(np.mean(valid_distances)) if len(valid_distances) else np.nan

    skipped_stops = max(n_soll - covered_count, 0)
    extra_points = max(n_ist - covered_count, 0)

    # Abweichungstyp festlegen 
    if covered_count == 0:
        deviation_type = "Kein räumliches Match"
    elif anyorder_coverage_ratio < 0.5:
        deviation_type = "Starke Abdeckungslücke"
    elif anyorder_coverage_ratio < 1.0 and not strictly_increasing:
        deviation_type = "Teilabdeckung + Reihenfolgefehler"
    elif anyorder_coverage_ratio < 1.0:
        deviation_type = "Ausgelassene Stopps"
    elif anyorder_coverage_ratio == 1.0 and not strictly_increasing:
        deviation_type = "Reihenfolge geändert"
    elif extra_points > n_soll * 0.5:
        deviation_type = "Viele Zusatzbewegungen"
    else:
        deviation_type = "Plannah"

    rows.append({
        "TOURNR": t,
        "ANZAHL_SOLL_STOPPS": n_soll,
        "ANZAHL_IST_PUNKTE": n_ist,
        "ABGEDECKTE_STOPPS": covered_count,
        "AUSGELASSENE_STOPPS": skipped_stops,
        "ZUSATZ_PUNKTE": extra_points,
        "COVERAGE_RATIO_STRIKT": round(strict_coverage_ratio, 4),
        "COVERAGE_RATIO_ANYORDER": round(anyorder_coverage_ratio, 4),
        "STRICTLY_INCREASING": strictly_increasing,
        "INVERSIONEN": inv_count,
        "MEAN_MATCH_DIST_M": round(mean_match_dist, 2) if pd.notna(mean_match_dist) else np.nan,
        "ABWEICHUNGSTYP": deviation_type
    })

tour_deviation_types = pd.DataFrame(rows).sort_values(
    ["ABWEICHUNGSTYP", "TOURNR"]
).reset_index(drop=True)

# CSV speichern
# tour_deviation_types.to_csv("tour_deviation_types.csv", index=False)

# Tabelle anzeigen
display(tour_deviation_types.head(20))

# Plot: Verteilung der Abweichungstypen
fig = px.bar(
    tour_deviation_types["ABWEICHUNGSTYP"].value_counts().reset_index(),
    x="count",
    y="ABWEICHUNGSTYP",
    orientation="h",
    title="Anzahl Touren je Abweichungstyp",
    labels={"count": "Anzahl Touren", "ABWEICHUNGSTYP": "Abweichungstyp"}
)

fig.update_layout(
    yaxis=dict(categoryorder="total ascending")
)
fig.update_traces(marker_color="#00498b")
fig.show()
# Out:
#      TOURNR  ANZAHL_SOLL_STOPPS  ANZAHL_IST_PUNKTE  ABGEDECKTE_STOPPS  \
# 0   H/42374                   4                  2                  0
# 1   H/42375                   6                  9                  0
# 2   H/42376                   8                  6                  0
# 3   H/42377                   5                  6                  0
# 4   H/42380                   4                  6                  0
# 5   H/42381                   9                 10                  0
# 6   H/42391                   4                  2                  0
# 7   H/42393                   6                  7                  0
# 8   H/42395                   6                  6                  0
# 9   H/42396                  11                 11                  0
# 10  H/42397                   4                  7                  0
# 11  H/42398                   8                  7                  0
# 12  H/42403                   6                  4                  0
# 13  H/42405                   6                 10                  0
# 14  H/42406                   7                  7                  0
# 15  H/42407                   9                  7                  0
# 16  H/42408                  12                 13                  0
# 17  H/42409                   4                  4                  0
# 18  H/42410                   3                  3                  0
# 19  H/42418                  12                  4                  0
#
#     AUSGELASSENE_STOPPS  ZUSATZ_PUNKTE  COVERAGE_RATIO_STRIKT  \
# 0                     4              2                    0.0
# 1                     6              9                    0.0
# 2                     8              6                    0.0
# 3                     5              6                    0.0
# 4                     4              6                    0.0
# 5                     9             10                    0.0
# 6                     4              2                    0.0
# 7                     6              7                    0.0
# 8                     6              6                    0.0
# 9                    11             11                    0.0
# 10                    4              7                    0.0
# 11                    8              7                    0.0
# 12                    6              4                    0.0
# 13                    6             10                    0.0
# 14                    7              7                    0.0
# 15                    9              7                    0.0
# 16                   12             13                    0.0
# 17                    4              4                    0.0
# 18                    3              3                    0.0
# 19                   12              4                    0.0
#
#     COVERAGE_RATIO_ANYORDER  STRICTLY_INCREASING  INVERSIONEN  \
# 0                       0.0                 True            0
# 1                       0.0                 True            0
# 2                       0.0                 True            0
# 3                       0.0                 True            0
# 4                       0.0                 True            0
# 5                       0.0                 True            0
# 6                       0.0                 True            0
# 7                       0.0                 True            0
# 8                       0.0                 True            0
# 9                       0.0                 True            0
# 10                      0.0                 True            0
# 11                      0.0                 True            0
# 12                      0.0                 True            0
# 13                      0.0                 True            0
# 14                      0.0                 True            0
# 15                      0.0                 True            0
# 16                      0.0                 True            0
# 17                      0.0                 True            0
# 18                      0.0                 True            0
# 19                      0.0                 True            0
#
#     MEAN_MATCH_DIST_M         ABWEICHUNGSTYP
# 0                 NaN  Kein räumliches Match
# 1                 NaN  Kein räumliches Match
# 2                 NaN  Kein räumliches Match
# 3                 NaN  Kein räumliches Match
# 4                 NaN  Kein räumliches Match
# 5                 NaN  Kein räumliches Match
# 6                 NaN  Kein räumliches Match
# 7                 NaN  Kein räumliches Match
# 8                 NaN  Kein räumliches Match
# 9                 NaN  Kein räumliches Match
# 10                NaN  Kein räumliches Match
# 11                NaN  Kein räumliches Match
# 12                NaN  Kein räumliches Match
# 13                NaN  Kein räumliches Match
# 14                NaN  Kein räumliches Match
# 15                NaN  Kein räumliches Match
# 16                NaN  Kein räumliches Match
# 17                NaN  Kein räumliches Match
# 18                NaN  Kein räumliches Match
# 19                NaN  Kein räumliches Match

# %%
tour_deviation_types[tour_deviation_types.TOURNR == 'H/42375']
# Out:
#     TOURNR  ANZAHL_SOLL_STOPPS  ANZAHL_IST_PUNKTE  ABGEDECKTE_STOPPS  \
# 1  H/42375                   6                  9                  0
#
#    AUSGELASSENE_STOPPS  ZUSATZ_PUNKTE  COVERAGE_RATIO_STRIKT  \
# 1                    6              9                    0.0
#
#    COVERAGE_RATIO_ANYORDER  STRICTLY_INCREASING  INVERSIONEN  \
# 1                      0.0                 True            0
#
#    MEAN_MATCH_DIST_M         ABWEICHUNGSTYP
# 1                NaN  Kein räumliches Match

# %%
soll[soll.TOURNR == 'H/42376']
# Out:
#      TOURNR  LKW_KENNZ         FAHRERNAME             ANKUNFT  \
# 10  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 06:00:00
# 11  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 06:49:00
# 12  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 07:41:00
# 13  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 08:31:00
# 14  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 09:23:00
# 15  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 10:00:00
# 16  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 10:37:00
# 17  H/42376  Plo-TS859  Krüger, Alexander 2026-03-02 11:14:00
#
#                 ABFAHRT     GEOX      GEOY      STOPP_DAUER       DATUM
# 10  2026-03-02 06:30:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 11  2026-03-02 07:19:00  9.99383  53.54751  0 days 00:30:00  2026-03-02
# 12  2026-03-02 08:11:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 13  2026-03-02 09:01:00  9.99383  53.54751  0 days 00:30:00  2026-03-02
# 14  2026-03-02 09:53:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 15  2026-03-02 10:30:00  9.98213  53.53497  0 days 00:30:00  2026-03-02
# 16  2026-03-02 11:07:00  9.98632  53.52348  0 days 00:30:00  2026-03-02
# 17  2026-03-02 11:44:00  9.98213  53.53497  0 days 00:30:00  2026-03-02
