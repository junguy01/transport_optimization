# %%
#!pip install openpyxl

# %%
#pip install -r requirements.txt

# %% [markdown]
# # Zusammenfassung Ergebnisse Notebook
# * Soll- mit Ist-Daten mergen
# * fügen allen Ist-Daten Tournummern zu anhand von Fahrer, Kennzeichen und Datum
# * manche Fahrer und Kennzeichen von den Soll-Daten sind gar nicht in den Ist-Daten
# * Datum 4.7. fehlt

# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %% [markdown]
# # Soll Daten einlesen aus CIS-Daten.xlsx

# %%
# Nur die gewünschten Spalten einlesen
cols = ['TOURNR', 'LKW_KENNZ', 'FAHRERNAME', 'TOUR', 'ANKUNFT', 'ABFAHRT', 'GEOX', 'GEOY']

df_soll = pd.read_excel('CIS-Daten.xlsx', usecols=cols)

df_soll.head()
# Out:
#     TOURNR  LKW_KENNZ        FAHRERNAME     TOUR           ANKUNFT  \
# 0  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:00
# 1  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:00
# 2  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:49
# 3  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 07:41
# 4  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 08:31
#
#             ABFAHRT     GEOX      GEOY
# 0  02.03.2026 06:00  9.98632  53.52348
# 1  02.03.2026 06:30  9.98632  53.52348
# 2  02.03.2026 07:19  9.99383  53.54751
# 3  02.03.2026 08:11  9.98632  53.52348
# 4  02.03.2026 09:01  9.99383  53.54751

# %% [markdown]
# Anzahl aller Zeilen mit einer Tournummer -> alle Zeilen der Soll-Daten haben eine Tournummer

# %%
# Anzahl aller Zeilen mit einer Tournummer (inkl. Duplikate)
print("alle zeilen: ", df_soll.shape)
print(df_soll['TOURNR'].count())
# Out:
# alle zeilen:  (2800, 8)
# 2800

# %% [markdown]
# Schauen, ob es Duplikate gibt in den Zeilen -> gibt es nur für Mafi Greif Fahrzeuge und die sollen laut Frank sowieso gelöscht werden

# %%
df_soll.duplicated().any()
# Out:
# np.True_

# %%
df_soll[df_soll.duplicated(keep=False)]
# Out:
#        TOURNR   LKW_KENNZ        FAHRERNAME     TOUR           ANKUNFT  \
# 1439  H/42521  Mafi Greif  Stoffer, Andreas  H/42521  19.03.2026 07:20
# 1440  H/42521  Mafi Greif  Stoffer, Andreas  H/42521  19.03.2026 07:20
# 1441  H/42521  Mafi Greif  Stoffer, Andreas  H/42521  19.03.2026 08:00
# 1442  H/42521  Mafi Greif  Stoffer, Andreas  H/42521  19.03.2026 08:00
#
#                ABFAHRT     GEOX      GEOY
# 1439  19.03.2026 07:40  9.98632  53.52348
# 1440  19.03.2026 07:40  9.98632  53.52348
# 1441  19.03.2026 08:20  9.98632  53.52348
# 1442  19.03.2026 08:20  9.98632  53.52348

# %% [markdown]
# ## Häufigkeit jeder Tournummer

# %%
# Häufigkeit jeder Tournummer
print(df_soll['TOURNR'].value_counts())
# Out:
# TOURNR
# H/42519    77
# H/42518    50
# H/42444    47
# H/42520    40
# H/42441    39
#            ..
# H/42446     3
# H/42638     3
# H/42605     3
# H/42606     3
# H/42675     3
# Name: count, Length: 265, dtype: int64

# %% [markdown]
# ### erste Tour hat 77 Stopps -> gucken da genauer rein -> Mafi Greif Fahrzeug, wird gelöscht

# %%
# Alle Einträge für Tournummer H/42519
df_tour = df_soll[df_soll['TOURNR'] == 'H/42519']

print(df_tour)
# Out:
#        TOURNR   LKW_KENNZ        FAHRERNAME     TOUR           ANKUNFT  \
# 1318  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 06:00
# 1319  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 06:00
# 1320  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 06:25
# 1321  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 06:45
# 1322  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 07:05
# ...       ...         ...               ...      ...               ...
# 1390  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 19:30
# 1391  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 19:45
# 1392  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 19:50
# 1393  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 20:05
# 1394  H/42519  Mafi Greif  Stoffer, Andreas  H/42519  17.03.2026 20:10
#
#                ABFAHRT     GEOX      GEOY
# 1318  17.03.2026 06:00  9.98632  53.52348
# 1319  17.03.2026 06:05  0.00000   0.00000
# 1320  17.03.2026 06:45  9.98632  53.52348
# 1321  17.03.2026 07:05  0.00000   0.00000
# 1322  17.03.2026 07:25  9.98632  53.52348
# ...                ...      ...       ...
# 1390  17.03.2026 19:45  9.98632  53.52348
# 1391  17.03.2026 19:50  9.98632  53.52348
# 1392  17.03.2026 20:05  9.98632  53.52348
# 1393  17.03.2026 20:10  9.98632  53.52348
# 1394  17.03.2026 20:25  9.98632  53.52348
#
# [77 rows x 8 columns]

# %% [markdown]
# ## Löschen der Mafi Greif Fahrzeuge (Anweisung von Frank)

# %%
df_soll = df_soll[df_soll['LKW_KENNZ'] != 'Mafi Greif']

# %%
# Häufigkeit jeder Tournummer
print(df_soll['TOURNR'].value_counts())
# Out:
# TOURNR
# H/42510    20
# H/42480    17
# H/42513    17
# H/42488    17
# H/42450    17
#            ..
# H/42570     3
# H/42638     3
# H/42675     3
# H/42696     3
# H/42722     3
# Name: count, Length: 240, dtype: int64

# %%
# Anzahl aller Zeilen mit einer Tournummer (inkl. Duplikate)
print(df_soll['TOURNR'].count())
# Out:
# 1991

# %%
df_soll
# Out:
#        TOURNR  LKW_KENNZ        FAHRERNAME     TOUR           ANKUNFT  \
# 0     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:00
# 1     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:00
# 2     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 06:49
# 3     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 07:41
# 4     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374  02.03.2026 08:31
# ...       ...        ...               ...      ...               ...
# 2795  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758  07.04.2026 06:00
# 2796  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758  07.04.2026 06:57
# 2797  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758  07.04.2026 07:53
# 2798  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758  07.04.2026 09:52
# 2799  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758  07.04.2026 11:52
#
#                ABFAHRT      GEOX      GEOY
# 0     02.03.2026 06:00   9.98632  53.52348
# 1     02.03.2026 06:30   9.98632  53.52348
# 2     02.03.2026 07:19   9.99383  53.54751
# 3     02.03.2026 08:11   9.98632  53.52348
# 4     02.03.2026 09:01   9.99383  53.54751
# ...                ...       ...       ...
# 2795  07.04.2026 06:00   9.98632  53.52348
# 2796  07.04.2026 07:27  10.09782  53.53610
# 2797  07.04.2026 08:23   9.98632  53.52348
# 2798  07.04.2026 10:22   9.51017  53.64711
# 2799  07.04.2026 11:52   9.98632  53.52348
#
# [1991 rows x 8 columns]

# %% [markdown]
# # Plausibilität zwischen Ankunft und Abfahrt
# * Ankunft muss zeitlich vor Abfahrt sein -> alles plausibel
# * Untersuchung der Stoppdauer

# %%
df_soll['ANKUNFT'] = pd.to_datetime(df_soll['ANKUNFT'], format='%d.%m.%Y %H:%M')
df_soll['ABFAHRT'] = pd.to_datetime(df_soll['ABFAHRT'], format='%d.%m.%Y %H:%M')

# Stoppdauer berechnen
df_soll['STOPP_DAUER'] = df_soll['ABFAHRT'] - df_soll['ANKUNFT']

# Fehlerhafte Einträge: Abfahrt vor Ankunft
fehler_zeit = df_soll[df_soll['STOPP_DAUER'] < pd.Timedelta(0)]
print(f"Zeitfehler: {len(fehler_zeit)} Einträge")
print(fehler_zeit)
# Out:
# Zeitfehler: 0 Einträge
# Empty DataFrame
# Columns: [TOURNR, LKW_KENNZ, FAHRERNAME, TOUR, ANKUNFT, ABFAHRT, GEOX, GEOY, STOPP_DAUER]
# Index: []

# %%
df_soll.nunique()
# Out:
# TOURNR          240
# LKW_KENNZ        14
# FAHRERNAME       15
# TOUR            240
# ANKUNFT        1516
# ABFAHRT        1593
# GEOX            237
# GEOY            238
# STOPP_DAUER      30
# dtype: int64

# %%
df_soll["FAHRERNAME"].unique()
# Out:
# array(['Hesse, Sven-Erik', 'Szmajdewicz, Marcin', 'Krüger, Alexander',
#        'Jorczik, Christian', 'Ledwina, Jens', 'Borrs, Thomas',
#        'Calina, Florin Alexandru', 'Oelschlaeger, Marcel',
#        'Giewon, Mariusz', 'Staben, Volker', 'Schulz, Frank',
#        'Teme, Abdoulaye', 'Hrzuska, Krzystof', 'Sowa, Mariusz', nan,
#        'Stoffer, Andreas'], dtype=object)

# %%
# Stopps pro Tour sortiert nach Ankunftszeit
df_sorted = df_soll.sort_values(['TOURNR', 'ANKUNFT'])

# Überblick: Wie viele Stopps hat jede Tour?
print(df_sorted.groupby('TOURNR').size().rename('Anzahl Stopps'))
# Out:
# TOURNR
# H/42374     6
# H/42375     7
# H/42376    10
# H/42377     6
# H/42378     6
#            ..
# H/42742    16
# H/42746     4
# H/42750     8
# H/42754     7
# H/42758     5
# Name: Anzahl Stopps, Length: 240, dtype: int64

# %% [markdown]
# ### Berechnung der Stoppdauer

# %%
df_soll['STOPP_DAUER'] = df_soll['ABFAHRT'] - df_soll['ANKUNFT']
fehler_zeit = df_soll[df_soll['STOPP_DAUER'] < pd.Timedelta(0)]
print(f"Zeitfehler: {len(fehler_zeit)} Einträge")
# Out:
# Zeitfehler: 0 Einträge

# %%
df_soll['STOPP_DAUER'].describe()
# Out:
# count                         1991
# mean     0 days 00:25:48.789552988
# std      0 days 00:33:14.678571708
# min                0 days 00:00:00
# 25%                0 days 00:15:00
# 50%                0 days 00:30:00
# 75%                0 days 00:30:00
# max                0 days 14:08:00
# Name: STOPP_DAUER, dtype: object

# %% [markdown]
# # Einlesen der Ist-Daten
# * 1 Excel pro Fahrzeug
# * loop durch alle Dateien, loop durch alle Blätter und dann Formularbeschreibung mit `Ankunft Kunde` und `Abfahrt Kunde` rausgesucht

# %%
dateien = [
    'Einzelmeldungsreport_HTS-Cargo_GmbH_1.xlsx',
    'Einzelmeldungsreport_HTS-Cargo_GmbH_2.xlsx',
    'Einzelmeldungsreport_HTS-Cargo_GmbH_3.xlsx',
    'Einzelmeldungsreport_HTS-Cargo_GmbH_4.xlsx',
    'Einzelmeldungsreport_HTS-Cargo_GmbH_5.xlsx',
]

ist_frames = []

for datei in dateien:
    alle_blaetter = pd.read_excel(datei, sheet_name=None, header=8)
    for blatt_name, blatt_df in alle_blaetter.items():
        if 'Formularbeschreibung' in blatt_df.columns:
            gefiltert = blatt_df[blatt_df['Formularbeschreibung'].isin(['Ankunft Kunde', 'Abfahrt Kunde'])].copy()
            gefiltert['Fahrzeug'] = blatt_name  # Fahrzeugname als Spalte speichern
            if not gefiltert.empty:
                ist_frames.append(gefiltert)

df_ist = pd.concat(ist_frames, ignore_index=True)
print(f"Ist-Daten: {len(df_ist)} Einträge")
print(df_ist.columns.tolist())
# Out:
# Ist-Daten: 2875 Einträge
# ['Fahrer PIN', 'Fahrername', 'Formularnummer', 'Formularbeschreibung', 'Meldungszeit', 'Richtung', 'Geschwindigkeit', 'KM-Stand', 'Gesamtverbrauch', 'Tankfüllstand', 'Breitengrad', 'Längengrad', 'Position', 'Meldungsquelle', 'Fahrzeug']

# %%
df_ist = df_ist.drop('Meldungsquelle', axis=1)
df_ist
# Out:
#       Fahrer PIN          Fahrername  Formularnummer Formularbeschreibung  \
# 0         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 1         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 2         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 3         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 4         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# ...          ...                 ...             ...                  ...
# 2870      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2871      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2872      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2873      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2874      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
#
#             Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  \
# 0    2026-03-24 05:19:13        74                0  316550.025
# 1    2026-03-24 07:00:13         0                0  316550.025
# 2    2026-03-24 07:33:59         0                0  316565.680
# 3    2026-03-24 07:34:00         0                0  316565.680
# 4    2026-03-24 07:54:21         0                0  316568.980
# ...                  ...       ...              ...         ...
# 2870 2026-03-06 11:49:13       208                0  502860.415
# 2871 2026-03-06 11:59:39         0                0  502863.510
# 2872 2026-03-06 12:11:29         0                0  502863.755
# 2873 2026-03-06 12:37:22         0                0  502869.170
# 2874 2026-03-06 13:04:35         0                0  502874.385
#
#       Gesamtverbrauch  Tankfüllstand Breitengrad Längengrad  \
# 0                 0.0            0.0    53,66758    9,99266
# 1                 0.0            0.0    53,66757     9,9928
# 2                 0.0            0.0    53,58982    9,91377
# 3                 0.0            0.0    53,58982    9,91377
# 4                 0.0            0.0    53,58884    9,87736
# ...               ...            ...         ...        ...
# 2870              0.0            0.0    53,51717    9,96982
# 2871              0.0            0.0    53,52261    9,98925
# 2872              0.0            0.0     53,5228    9,98903
# 2873              0.0            0.0     53,5341    9,98237
# 2874              0.0            0.0    53,52344    9,98587
#
#                                                Position  \
# 0     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 2     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 3     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 4     DE - 22547 Hamburg (Lurup), Elbgaustraße (Ring...
# ...                                                 ...
# 2870  DE - 20457 Hamburg (Hamburg-Mitte), Köhlbrandb...
# 2871  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2872  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2873   DE - 20457 Hamburg (Hamburg-Mitte), Worthdamm 32
# 2874  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
#
#                           Fahrzeug
# 0     OD-TS 8041 - Fahrzeugdetails
# 1     OD-TS 8041 - Fahrzeugdetails
# 2     OD-TS 8041 - Fahrzeugdetails
# 3     OD-TS 8041 - Fahrzeugdetails
# 4     OD-TS 8041 - Fahrzeugdetails
# ...                            ...
# 2870       TS859 - Fahrzeugdetails
# 2871       TS859 - Fahrzeugdetails
# 2872       TS859 - Fahrzeugdetails
# 2873       TS859 - Fahrzeugdetails
# 2874       TS859 - Fahrzeugdetails
#
# [2875 rows x 14 columns]

# %% [markdown]
# ### Mafi rausfiltern falls enthalten

# %%
df_ist = df_ist[~df_ist['Fahrzeug'].str.contains('Mafi', case=False, na=False)]

# %%
df_ist
# Out:
#       Fahrer PIN          Fahrername  Formularnummer Formularbeschreibung  \
# 0         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 1         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 2         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 3         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 4         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# ...          ...                 ...             ...                  ...
# 2870      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2871      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2872      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2873      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2874      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
#
#             Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  \
# 0    2026-03-24 05:19:13        74                0  316550.025
# 1    2026-03-24 07:00:13         0                0  316550.025
# 2    2026-03-24 07:33:59         0                0  316565.680
# 3    2026-03-24 07:34:00         0                0  316565.680
# 4    2026-03-24 07:54:21         0                0  316568.980
# ...                  ...       ...              ...         ...
# 2870 2026-03-06 11:49:13       208                0  502860.415
# 2871 2026-03-06 11:59:39         0                0  502863.510
# 2872 2026-03-06 12:11:29         0                0  502863.755
# 2873 2026-03-06 12:37:22         0                0  502869.170
# 2874 2026-03-06 13:04:35         0                0  502874.385
#
#       Gesamtverbrauch  Tankfüllstand Breitengrad Längengrad  \
# 0                 0.0            0.0    53,66758    9,99266
# 1                 0.0            0.0    53,66757     9,9928
# 2                 0.0            0.0    53,58982    9,91377
# 3                 0.0            0.0    53,58982    9,91377
# 4                 0.0            0.0    53,58884    9,87736
# ...               ...            ...         ...        ...
# 2870              0.0            0.0    53,51717    9,96982
# 2871              0.0            0.0    53,52261    9,98925
# 2872              0.0            0.0     53,5228    9,98903
# 2873              0.0            0.0     53,5341    9,98237
# 2874              0.0            0.0    53,52344    9,98587
#
#                                                Position  \
# 0     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 2     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 3     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 4     DE - 22547 Hamburg (Lurup), Elbgaustraße (Ring...
# ...                                                 ...
# 2870  DE - 20457 Hamburg (Hamburg-Mitte), Köhlbrandb...
# 2871  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2872  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2873   DE - 20457 Hamburg (Hamburg-Mitte), Worthdamm 32
# 2874  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
#
#                           Fahrzeug
# 0     OD-TS 8041 - Fahrzeugdetails
# 1     OD-TS 8041 - Fahrzeugdetails
# 2     OD-TS 8041 - Fahrzeugdetails
# 3     OD-TS 8041 - Fahrzeugdetails
# 4     OD-TS 8041 - Fahrzeugdetails
# ...                            ...
# 2870       TS859 - Fahrzeugdetails
# 2871       TS859 - Fahrzeugdetails
# 2872       TS859 - Fahrzeugdetails
# 2873       TS859 - Fahrzeugdetails
# 2874       TS859 - Fahrzeugdetails
#
# [2875 rows x 14 columns]

# %% [markdown]
# ### Datum aus Soll Daten und Ist Daten extrahieren zum Tournummern zuordnen

# %%
# Soll-Daten: Datum aus ANKUNFT extrahieren
df_soll['DATUM'] = df_soll['ANKUNFT'].dt.date

# Ist-Daten: Meldungszeit parsen und Datum extrahieren
df_ist['Meldungszeit'] = pd.to_datetime(df_ist['Meldungszeit'], format='%d.%m.%Y %H:%M:%S', errors='coerce')
df_ist['DATUM'] = df_ist['Meldungszeit'].dt.date

# %%
df_ist.head()
# Out:
#    Fahrer PIN          Fahrername  Formularnummer Formularbeschreibung  \
# 0      8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 1      8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 2      8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 3      8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 4      8160.0  Jorczik, Christian            1650        Ankunft Kunde
#
#          Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  Gesamtverbrauch  \
# 0 2026-03-24 05:19:13        74                0  316550.025              0.0
# 1 2026-03-24 07:00:13         0                0  316550.025              0.0
# 2 2026-03-24 07:33:59         0                0  316565.680              0.0
# 3 2026-03-24 07:34:00         0                0  316565.680              0.0
# 4 2026-03-24 07:54:21         0                0  316568.980              0.0
#
#    Tankfüllstand Breitengrad Längengrad  \
# 0            0.0    53,66758    9,99266
# 1            0.0    53,66757     9,9928
# 2            0.0    53,58982    9,91377
# 3            0.0    53,58982    9,91377
# 4            0.0    53,58884    9,87736
#
#                                             Position  \
# 0  DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1  DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 2  DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 3  DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 4  DE - 22547 Hamburg (Lurup), Elbgaustraße (Ring...
#
#                        Fahrzeug       DATUM
# 0  OD-TS 8041 - Fahrzeugdetails  2026-03-24
# 1  OD-TS 8041 - Fahrzeugdetails  2026-03-24
# 2  OD-TS 8041 - Fahrzeugdetails  2026-03-24
# 3  OD-TS 8041 - Fahrzeugdetails  2026-03-24
# 4  OD-TS 8041 - Fahrzeugdetails  2026-03-24

# %%
df_soll.head()
# Out:
#     TOURNR  LKW_KENNZ        FAHRERNAME     TOUR             ANKUNFT  \
# 0  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 1  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 2  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:49:00
# 3  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 07:41:00
# 4  H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 08:31:00
#
#               ABFAHRT     GEOX      GEOY     STOPP_DAUER       DATUM
# 0 2026-03-02 06:00:00  9.98632  53.52348 0 days 00:00:00  2026-03-02
# 1 2026-03-02 06:30:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 2 2026-03-02 07:19:00  9.99383  53.54751 0 days 00:30:00  2026-03-02
# 3 2026-03-02 08:11:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 4 2026-03-02 09:01:00  9.99383  53.54751 0 days 00:30:00  2026-03-02

# %% [markdown]
# ## Vergleich von Soll- und Ist-Daten

# %%
df_ist.nunique()
# Out:
# Fahrer PIN                11
# Fahrername                11
# Formularnummer             2
# Formularbeschreibung       2
# Meldungszeit            2753
# Richtung                 314
# Geschwindigkeit            5
# KM-Stand                1421
# Gesamtverbrauch          637
# Tankfüllstand            176
# Breitengrad             1066
# Längengrad              1294
# Position                 375
# Fahrzeug                  12
# DATUM                     24
# dtype: int64

# %%
df_soll.nunique()
# Out:
# TOURNR          240
# LKW_KENNZ        14
# FAHRERNAME       15
# TOUR            240
# ANKUNFT        1516
# ABFAHRT        1593
# GEOX            237
# GEOY            238
# STOPP_DAUER      30
# DATUM            25
# dtype: int64

# %% [markdown]
# ### Erkenntnisse:
# * in Soll-Daten mehr Fahrer und mehr Kennzeichen als in Ist-Daten
# * in Soll-Daten ein Datum mehr
# * Ist-Daten haben wesentlich mehr Breiten-/Längengrade als Soll-Daten
#
# ## Fahrzeugdetails
# * jedes Blatt hat im Titel das Kennzeichen

# %%
df_ist['Fahrzeug'].unique()
# Out:
# array(['OD-TS 8041 - Fahrzeugdetails', 'OD-TS 8046 - Fahrzeugdetails',
#        'OD-TS 8048 - Fahrzeugdetails', 'OD-TS 8050 - Fahrzeugdetails',
#        'PI-EN 444 - Fahrzeugdetails', 'PI-EN 900 - Fahrzeugdetails',
#        'Plo-TS857 - Fahrzeugdetails', 'Plö-TS853 - Fahrzeugdetails',
#        'Plö-TS856 - Fahrzeugdetails', 'TS859 - Fahrzeugdetails',
#        'WL-PL431 - Fahrzeugdetails', 'OD-TS 8044 - Fahrzeugdetails'],
#       dtype=object)

# %% [markdown]
# ## Schreibfehler/Unterschiede zwischen den Fahrernamen (bei gleichem Fahrer) -> darum kümmern wir uns nach den Kennzeichen weiter untern

# %%
df_ist['Fahrername'].unique()
# Out:
# array(['Jorczik, Christian', 'Calina, Florin Alexandru',
#        'Oelschläger, Marcel', 'Szmajdewicz, Marcin', 'Giewon, Mariusz',
#        'Teme, Abdoulaeye', 'Ledwina, Jens', 'Borrs, Thomas',
#        'Hesse, Sven-Erik', 'Krüger, Alexander', 'Hruszka, Krzysztof'],
#       dtype=object)

# %%
df_soll['FAHRERNAME'].unique()
# Out:
# array(['Hesse, Sven-Erik', 'Szmajdewicz, Marcin', 'Krüger, Alexander',
#        'Jorczik, Christian', 'Ledwina, Jens', 'Borrs, Thomas',
#        'Calina, Florin Alexandru', 'Oelschlaeger, Marcel',
#        'Giewon, Mariusz', 'Staben, Volker', 'Schulz, Frank',
#        'Teme, Abdoulaye', 'Hrzuska, Krzystof', 'Sowa, Mariusz', nan,
#        'Stoffer, Andreas'], dtype=object)

# %%
df_ist['DATUM'].unique()
# Out:
# array([datetime.date(2026, 3, 24), datetime.date(2026, 3, 25),
#        datetime.date(2026, 3, 26), datetime.date(2026, 3, 23),
#        datetime.date(2026, 3, 27), datetime.date(2026, 3, 30),
#        datetime.date(2026, 3, 31), datetime.date(2026, 4, 1),
#        datetime.date(2026, 4, 2), datetime.date(2026, 3, 16),
#        datetime.date(2026, 3, 17), datetime.date(2026, 3, 19),
#        datetime.date(2026, 3, 18), datetime.date(2026, 3, 20),
#        datetime.date(2026, 3, 10), datetime.date(2026, 3, 11),
#        datetime.date(2026, 3, 12), datetime.date(2026, 3, 13),
#        datetime.date(2026, 3, 9), datetime.date(2026, 3, 2),
#        datetime.date(2026, 3, 4), datetime.date(2026, 3, 5),
#        datetime.date(2026, 3, 3), datetime.date(2026, 3, 6)], dtype=object)

# %% [markdown]
# ## Gesamtanzahl Fahrten

# %%
# Gesamtanzahl Fahrten (eindeutige Fahrername + Datum Kombinationen)
anzahl_fahrten = df_ist.groupby(['Fahrername', 'DATUM']).ngroups
print(f"Gesamtanzahl Fahrten: {anzahl_fahrten}")
# Out:
# Gesamtanzahl Fahrten: 213

# %% [markdown]
# Es gibt Tage mit mehreren Touren. Maximalanzahl der Touren pro Tag ist 3.

# %%
df_soll.groupby(['FAHRERNAME', 'DATUM'])['TOURNR'].nunique().max()
# Wenn > 1, gibt es Tage mit mehreren Touren
# Out:
# np.int64(3)

# %% [markdown]
# ## Eindeutige Touren pro Fahrer und Tag
# Wie oft mehr als 1 Tour pro Tag?

# %%
# Anzahl eindeutiger Touren pro Fahrer + Tag
touren_pro_tag = df_soll.groupby(['FAHRERNAME', 'DATUM'])['TOURNR'].nunique()

# Wie oft gibt es mehr als 1 Tour pro Tag
print((touren_pro_tag > 1).sum(), "Fahrer-Tag-Kombinationen mit mehr als 1 Tour")
print(touren_pro_tag.value_counts().sort_index())
# Out:
# 9 Fahrer-Tag-Kombinationen mit mehr als 1 Tour
# TOURNR
# 1    220
# 2      7
# 3      2
# Name: count, dtype: int64

# %% [markdown]
# ## Umgang mit Tagen, die mehr als eine Tour haben

# %%
# Tage mit mehr als 1 Tour identifizieren
touren_pro_tag = df_soll.groupby(['FAHRERNAME', 'DATUM'])['TOURNR'].nunique()
mehrfach_mask = touren_pro_tag[touren_pro_tag > 1].reset_index()
mehrfach_mask.columns = ['FAHRERNAME', 'DATUM', 'ANZAHL_TOUREN']

# Tournummern und Kennzeichen dazu joinen
details = df_soll.groupby(['FAHRERNAME', 'DATUM']).agg(
    TOURNUMMERN=('TOURNR', lambda x: ', '.join(x.unique())),
    KENNZEICHEN=('LKW_KENNZ', lambda x: ', '.join(x.unique()))
).reset_index()

# Zusammenführen
ergebnis = mehrfach_mask.merge(details, on=['FAHRERNAME', 'DATUM']).sort_values(['ANZAHL_TOUREN', 'DATUM'], ascending=[False, True])

print(ergebnis.to_string(index=False))
# Out:
#               FAHRERNAME      DATUM  ANZAHL_TOUREN               TOURNUMMERN                    KENNZEICHEN
#      Szmajdewicz, Marcin 2026-03-19              3 H/42547, H/42549, H/42556 PI-EN 900, OD-TS8050, WL-PL431
#      Szmajdewicz, Marcin 2026-03-20              3 H/42561, H/42568, H/42587 OD-TS8050, WL-PL431, PI-EN 900
#        Krüger, Alexander 2026-03-03              2          H/42393, H/42415           Plo-TS859, PI-EN 900
#          Teme, Abdoulaye 2026-03-11              2          H/42468, H/42505           PI-EN 900, OD-TS8050
#      Szmajdewicz, Marcin 2026-03-18              2          H/42536, H/42544            OD-TS8050, WL-PL431
# Calina, Florin Alexandru 2026-03-23              2          H/42571, H/42578           PI-EN 900, OD-TS8046
# Calina, Florin Alexandru 2026-03-26              2          H/42601, H/42628            OD-TS8046, WL-PL431
#        Krüger, Alexander 2026-03-31              2          H/42646, H/42657                      Plo-TS859
#     Oelschlaeger, Marcel 2026-04-01              2          H/42681, H/42695            OD-TS8048, WL-PL431

# %% [markdown]
# ### Erkenntnisse:
# * manche Fahrer haben für denselben Tag mehrere Tournummern und mehrere Kennzeichen,
# Überlegung ist nun so die Tournummern zuzuordnen wenn Kennzeichen, Datum und Person übereinstimmen.
# Für diesen Fall gibt es nur eine Ausnahme, siehe Krüger Alexander am 31.3 ist zwei Touren mit dem selben Fahrzeug gefahren.
#
# Deshalb werden wir folgt die Kennzeichen von df_ist mit denen von df_soll anpassen (es gibt wieder Probleme mit umlauten zb.)

# %%
df_soll
# Out:
#        TOURNR  LKW_KENNZ        FAHRERNAME     TOUR             ANKUNFT  \
# 0     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 1     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 2     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:49:00
# 3     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 07:41:00
# 4     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 08:31:00
# ...       ...        ...               ...      ...                 ...
# 2795  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:00:00
# 2796  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:57:00
# 2797  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 07:53:00
# 2798  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 09:52:00
# 2799  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 11:52:00
#
#                  ABFAHRT      GEOX      GEOY     STOPP_DAUER       DATUM
# 0    2026-03-02 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-03-02
# 1    2026-03-02 06:30:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 2    2026-03-02 07:19:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# 3    2026-03-02 08:11:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 4    2026-03-02 09:01:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# ...                  ...       ...       ...             ...         ...
# 2795 2026-04-07 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
# 2796 2026-04-07 07:27:00  10.09782  53.53610 0 days 00:30:00  2026-04-07
# 2797 2026-04-07 08:23:00   9.98632  53.52348 0 days 00:30:00  2026-04-07
# 2798 2026-04-07 10:22:00   9.51017  53.64711 0 days 00:30:00  2026-04-07
# 2799 2026-04-07 11:52:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
#
# [1991 rows x 10 columns]

# %% [markdown]
# ### Blatttitel beinhaltet auch das Kennzeichen des Fahrzeugs -> Extrahieren des Kennzeichens

# %%
df_ist["Fahrzeug"].unique()
# Out:
# array(['OD-TS 8041 - Fahrzeugdetails', 'OD-TS 8046 - Fahrzeugdetails',
#        'OD-TS 8048 - Fahrzeugdetails', 'OD-TS 8050 - Fahrzeugdetails',
#        'PI-EN 444 - Fahrzeugdetails', 'PI-EN 900 - Fahrzeugdetails',
#        'Plo-TS857 - Fahrzeugdetails', 'Plö-TS853 - Fahrzeugdetails',
#        'Plö-TS856 - Fahrzeugdetails', 'TS859 - Fahrzeugdetails',
#        'WL-PL431 - Fahrzeugdetails', 'OD-TS 8044 - Fahrzeugdetails'],
#       dtype=object)

# %%
df_soll["LKW_KENNZ"].unique()
# Out:
# array(['Plo-TS856', 'OD-TS8050', 'Plo-TS859', 'OD-TS8041', 'OD-TS8044',
#        'Plö-TS853', 'OD-TS8046', 'OD-TS8048', 'PI-EN 444', 'RW435',
#        'PI-EN 900', 'WL-PL431', 'Leihwagen', 'Plö-TS857'], dtype=object)

# %%
# Endung " - Fahrzeugdetails" entfernen
df_ist['KENNZ_CLEAN'] = df_ist['Fahrzeug'].str.replace(' - Fahrzeugdetails', '', regex=False)

# OD-TS Leerzeichen entfernen
df_ist['KENNZ_CLEAN'] = df_ist['KENNZ_CLEAN'].str.replace('OD-TS ', 'OD-TS', regex=False)

# Manuelle Korrekturen
korrekturen = {
    'Plo-TS857': 'Plö-TS857',
    'Plö-TS856': 'Plo-TS856',
    'TS859':     'Plo-TS859'
}
df_ist['KENNZ_CLEAN'] = df_ist['KENNZ_CLEAN'].replace(korrekturen)

# %%
df_soll["LKW_KENNZ"].unique()
# Out:
# array(['Plo-TS856', 'OD-TS8050', 'Plo-TS859', 'OD-TS8041', 'OD-TS8044',
#        'Plö-TS853', 'OD-TS8046', 'OD-TS8048', 'PI-EN 444', 'RW435',
#        'PI-EN 900', 'WL-PL431', 'Leihwagen', 'Plö-TS857'], dtype=object)

# %%
df_ist['KENNZ_CLEAN'].unique()
# Out:
# array(['OD-TS8041', 'OD-TS8046', 'OD-TS8048', 'OD-TS8050', 'PI-EN 444',
#        'PI-EN 900', 'Plö-TS857', 'Plö-TS853', 'Plo-TS856', 'Plo-TS859',
#        'WL-PL431', 'OD-TS8044'], dtype=object)

# %% [markdown]
# Kennzeichen von Soll- und Ist-Daten sind nun gleich

# %% [markdown]
# ## Untersuchung und Korrektur der Fahrernamen bei Umstimmigkeiten zwischen Soll- und Ist-Daten
# Am Ende sollen die Fahrernamen gleich sein.

# %%
df_soll["FAHRERNAME"].unique()
# Out:
# array(['Hesse, Sven-Erik', 'Szmajdewicz, Marcin', 'Krüger, Alexander',
#        'Jorczik, Christian', 'Ledwina, Jens', 'Borrs, Thomas',
#        'Calina, Florin Alexandru', 'Oelschlaeger, Marcel',
#        'Giewon, Mariusz', 'Staben, Volker', 'Schulz, Frank',
#        'Teme, Abdoulaye', 'Hrzuska, Krzystof', 'Sowa, Mariusz', nan,
#        'Stoffer, Andreas'], dtype=object)

# %%
df_ist['Fahrername'].unique()
# Out:
# array(['Jorczik, Christian', 'Calina, Florin Alexandru',
#        'Oelschläger, Marcel', 'Szmajdewicz, Marcin', 'Giewon, Mariusz',
#        'Teme, Abdoulaeye', 'Ledwina, Jens', 'Borrs, Thomas',
#        'Hesse, Sven-Erik', 'Krüger, Alexander', 'Hruszka, Krzysztof'],
#       dtype=object)

# %%
namen_korrekturen = {
    'Oelschläger, Marcel': 'Oelschlaeger, Marcel',
    'Teme, Abdoulaeye':    'Teme, Abdoulaye',
    'Hruszka, Krzysztof':  'Hrzuska, Krzystof'  # df_soll als Referenz
}

df_ist['Fahrername'] = df_ist['Fahrername'].replace(namen_korrekturen)

# Kontrolle
print(set(df_ist['Fahrername'].unique()) - set(df_soll['FAHRERNAME'].unique()))
# sollte set() ausgeben
# Out:
# set()

# %%
print(set(df_ist['KENNZ_CLEAN'].unique()) - set(df_soll['LKW_KENNZ'].unique()))
# Out:
# set()

# %% [markdown]
# Hier schauen welche Touren sich nicht eindeutig durch Name, Kennzeichen und Datum unterscheiden.

# %%
touren_detail = df_soll.groupby(['FAHRERNAME', 'LKW_KENNZ', 'DATUM'])['TOURNR'].nunique()

# Nur die mit mehr als 1 Tour
mehrfach = touren_detail[touren_detail > 1].reset_index()
mehrfach.columns = ['FAHRERNAME', 'LKW_KENNZ', 'DATUM', 'ANZAHL_TOUREN']

# %%
# Tournummern dazu
tournr = df_soll.groupby(['FAHRERNAME', 'LKW_KENNZ', 'DATUM'])['TOURNR'].apply(lambda x: ', '.join(x.unique())).reset_index()
tournr.columns = ['FAHRERNAME', 'LKW_KENNZ', 'DATUM', 'TOURNUMMERN']

ergebnis = mehrfach.merge(tournr, on=['FAHRERNAME', 'LKW_KENNZ', 'DATUM']).sort_values(['ANZAHL_TOUREN', 'DATUM'], ascending=[False, True])

print(f"Anzahl betroffener Fahrer-Fahrzeug-Tag Kombinationen: {len(ergebnis)}")
print(ergebnis.to_string(index=False))
# Out:
# Anzahl betroffener Fahrer-Fahrzeug-Tag Kombinationen: 1
#        FAHRERNAME LKW_KENNZ      DATUM  ANZAHL_TOUREN      TOURNUMMERN
# Krüger, Alexander Plo-TS859 2026-03-31              2 H/42646, H/42657

# %%
# Schritt 1: Eindeutiges Mapping erstellen (eine Tournr pro Fahrer+Kennz+Datum)
tour_mapping = df_soll.groupby(['FAHRERNAME', 'LKW_KENNZ', 'DATUM'])['TOURNR'].apply(lambda x: x.iloc[0]).reset_index()  # erstmal erste Tour nehmen
tour_mapping.columns = ['Fahrername', 'KENNZ_CLEAN', 'DATUM', 'TOURNR']

# Schritt 2: Merge auf df_ist
df_ist_merged = df_ist.merge(tour_mapping, on=['Fahrername', 'KENNZ_CLEAN', 'DATUM'], how='left')

# Schritt 3: Kontrolle
print(df_ist_merged['TOURNR'].isna().sum(), "Zeilen ohne Tournummer")
print(df_ist_merged['TOURNR'].notna().sum(), "Zeilen mit Tournummer")
# Out:
# 261 Zeilen ohne Tournummer
# 2614 Zeilen mit Tournummer

# %% [markdown]
# Im Fall Krüger wurde hier nur H/42646 zugewiesen. Da es nur der Einzelfall ist schien das einfacher!
# Damit können wir uns erstmal um die groben Fälle kümmern und diese untersuchen.

# %% [markdown]
# Nun wurden die Tournummern zu df_ist hinzugefügt, das hat größtenteils geklappt, es gibt circa 10 Prozent von Fällen, wo es nicht geklappt hat, das untersuchen wir weiter unten.

# %% [markdown]
# ### Untersuchung welche touren nicht zugeordnet werden konnten

# %%
df_ist_merged[df_ist_merged.TOURNR.isna()]
# Out:
#       Fahrer PIN           Fahrername  Formularnummer Formularbeschreibung  \
# 253       8314.0      Teme, Abdoulaye            1650        Ankunft Kunde
# 254       8314.0      Teme, Abdoulaye            1651        Abfahrt Kunde
# 255       8314.0      Teme, Abdoulaye            1650        Ankunft Kunde
# 256       8314.0      Teme, Abdoulaye            1651        Abfahrt Kunde
# 480       8311.0  Szmajdewicz, Marcin            1650        Ankunft Kunde
# ...          ...                  ...             ...                  ...
# 2702      8197.0    Hrzuska, Krzystof            1651        Abfahrt Kunde
# 2703      8197.0    Hrzuska, Krzystof            1650        Ankunft Kunde
# 2704      8197.0    Hrzuska, Krzystof            1651        Abfahrt Kunde
# 2705      8317.0     Hesse, Sven-Erik            1650        Ankunft Kunde
# 2706      8317.0     Hesse, Sven-Erik            1651        Abfahrt Kunde
#
#             Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  \
# 253  2026-03-23 11:45:25         0                0  143826.335
# 254  2026-03-23 11:45:26         0                0  143826.335
# 255  2026-03-23 14:09:15         0                0  143909.580
# 256  2026-03-23 14:09:16         0                0  143909.580
# 480  2026-03-24 07:48:59       329                0  807302.125
# ...                  ...       ...              ...         ...
# 2702 2026-03-06 13:50:54         0                0  179191.380
# 2703 2026-03-06 13:50:57         0                0  179191.380
# 2704 2026-03-06 13:50:59         0                0  179191.380
# 2705 2026-03-03 06:55:23         0                0  143469.000
# 2706 2026-03-03 09:19:42         0                0  143469.515
#
#       Gesamtverbrauch  Tankfüllstand Breitengrad Längengrad  \
# 253         45835.272           44.0    53,51678    9,96972
# 254         45835.272           44.0    53,51678    9,96972
# 255         45861.824           24.0    53,63088    9,50845
# 256         45861.824           24.0    53,63088    9,50845
# 480             0.000            0.0    53,52322    9,98857
# ...               ...            ...         ...        ...
# 2702        50937.052           32.0     53,5226    9,98912
# 2703        50937.052           32.0     53,5226    9,98912
# 2704        50937.052           32.0     53,5226    9,98912
# 2705        45685.036            4.8    53,53563    9,97776
# 2706        45685.880            6.0    53,53433     9,9806
#
#                                                Position  \
# 253   DE - 20457 Hamburg (Hamburg-Mitte), Neuhöfer D...
# 254   DE - 20457 Hamburg (Hamburg-Mitte), Neuhöfer D...
# 255                 DE - 21683 Stade, Stader Elbstraße
# 256                 DE - 21683 Stade, Stader Elbstraße
# 480   DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# ...                                                 ...
# 2702  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2703  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2704  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2705  DE - 20457 Hamburg (Hamburg-Mitte), Stillhorne...
# 2706  DE - 20457 Hamburg (Hamburg-Mitte), Werftstraße 5
#
#                          Fahrzeug       DATUM KENNZ_CLEAN TOURNR
# 253   PI-EN 900 - Fahrzeugdetails  2026-03-23   PI-EN 900    NaN
# 254   PI-EN 900 - Fahrzeugdetails  2026-03-23   PI-EN 900    NaN
# 255   PI-EN 900 - Fahrzeugdetails  2026-03-23   PI-EN 900    NaN
# 256   PI-EN 900 - Fahrzeugdetails  2026-03-23   PI-EN 900    NaN
# 480    WL-PL431 - Fahrzeugdetails  2026-03-24    WL-PL431    NaN
# ...                           ...         ...         ...    ...
# 2702  PI-EN 444 - Fahrzeugdetails  2026-03-06   PI-EN 444    NaN
# 2703  PI-EN 444 - Fahrzeugdetails  2026-03-06   PI-EN 444    NaN
# 2704  PI-EN 444 - Fahrzeugdetails  2026-03-06   PI-EN 444    NaN
# 2705  PI-EN 900 - Fahrzeugdetails  2026-03-03   PI-EN 900    NaN
# 2706  PI-EN 900 - Fahrzeugdetails  2026-03-03   PI-EN 900    NaN
#
# [261 rows x 17 columns]

# %%
# Welche Fahrer-Kennz-Datum Kombinationen haben kein Match?
keine_tour = df_ist_merged[df_ist_merged['TOURNR'].isna()]

print("Fehlende Matches nach Fahrer")
print(keine_tour.groupby('Fahrername').size().sort_values(ascending=False))

print("\nFehlende Matches nach KENNZ_CLEAN")
print(keine_tour.groupby('KENNZ_CLEAN').size().sort_values(ascending=False))

print("\nFehlende Matches nach DATUM")
print(keine_tour.groupby('DATUM').size().sort_values(ascending=False))

print("\nFahrer+Kennz+Datum ohne Match")
print(keine_tour.groupby(['Fahrername', 'KENNZ_CLEAN', 'DATUM']).size().reset_index().to_string(index=False))
# Out:
# Fehlende Matches nach Fahrer
# Fahrername
# Hrzuska, Krzystof           224
# Teme, Abdoulaye              22
# Szmajdewicz, Marcin           8
# Calina, Florin Alexandru      4
# Hesse, Sven-Erik              2
# Ledwina, Jens                 1
# dtype: int64
#
# Fehlende Matches nach KENNZ_CLEAN
# KENNZ_CLEAN
# PI-EN 444    138
# OD-TS8050     70
# WL-PL431      35
# PI-EN 900     17
# OD-TS8044      1
# dtype: int64
#
# Fehlende Matches nach DATUM
# DATUM
# 2026-03-19    37
# 2026-03-05    33
# 2026-03-06    29
# 2026-03-02    28
# 2026-03-03    26
# 2026-03-04    24
# 2026-03-20    21
# 2026-03-18    20
# 2026-03-13    20
# 2026-03-24     8
# 2026-03-09     4
# 2026-03-23     4
# 2026-04-01     4
# 2026-03-26     3
# dtype: int64
#
# Fahrer+Kennz+Datum ohne Match
#               Fahrername KENNZ_CLEAN      DATUM  0
# Calina, Florin Alexandru   OD-TS8050 2026-03-09  4
#         Hesse, Sven-Erik   PI-EN 900 2026-03-03  2
#        Hrzuska, Krzystof   OD-TS8050 2026-03-18 20
#        Hrzuska, Krzystof   OD-TS8050 2026-03-19 26
#        Hrzuska, Krzystof   OD-TS8050 2026-03-20 20
#        Hrzuska, Krzystof   PI-EN 444 2026-03-02 28
#        Hrzuska, Krzystof   PI-EN 444 2026-03-03 24
#        Hrzuska, Krzystof   PI-EN 444 2026-03-04 24
#        Hrzuska, Krzystof   PI-EN 444 2026-03-05 33
#        Hrzuska, Krzystof   PI-EN 444 2026-03-06 29
#        Hrzuska, Krzystof    WL-PL431 2026-03-13 20
#            Ledwina, Jens   OD-TS8044 2026-03-20  1
#      Szmajdewicz, Marcin    WL-PL431 2026-03-24  8
#          Teme, Abdoulaye   PI-EN 900 2026-03-19 11
#          Teme, Abdoulaye   PI-EN 900 2026-03-23  4
#          Teme, Abdoulaye    WL-PL431 2026-03-26  3
#          Teme, Abdoulaye    WL-PL431 2026-04-01  4

# %% [markdown]
# Sind die Beiden Fahrer Ersatzfahrer für Krankheitsfälle?

# %%
# 1. Welche Kennzeichen fährt Hrzuska in df_ist?
print("Hrzuska in df_ist")
print(df_ist[df_ist['Fahrername'] == 'Hrzuska, Krzystof'].groupby(['KENNZ_CLEAN', 'DATUM']).size().reset_index().to_string(index=False))

# 2. Welche Kennzeichen hat Hrzuska in df_soll?
print("\nHrzuska in df_soll")
print(df_soll[df_soll['FAHRERNAME'] == 'Hrzuska, Krzystof'].groupby(['LKW_KENNZ', 'DATUM']).size().reset_index().to_string(index=False))

# 3. Für Teme - welche Kennzeichen fehlen?
print("\nTeme in df_ist")
keine_tour = df_ist_merged[df_ist_merged['TOURNR'].isna()]
print(keine_tour[keine_tour['Fahrername'] == 'Teme, Abdoulaye'].groupby(['KENNZ_CLEAN', 'DATUM']).size().reset_index().to_string(index=False))

print("\nTeme in df_soll")
print(df_soll[df_soll['FAHRERNAME'] == 'Teme, Abdoulaye'].groupby(['LKW_KENNZ', 'DATUM']).size().reset_index().to_string(index=False))
# Out:
# Hrzuska in df_ist
# KENNZ_CLEAN      DATUM  0
#   OD-TS8050 2026-03-17 25
#   OD-TS8050 2026-03-18 20
#   OD-TS8050 2026-03-19 26
#   OD-TS8050 2026-03-20 20
#   PI-EN 444 2026-03-02 28
#   PI-EN 444 2026-03-03 24
#   PI-EN 444 2026-03-04 24
#   PI-EN 444 2026-03-05 33
#   PI-EN 444 2026-03-06 29
#   PI-EN 900 2026-03-16 22
#    WL-PL431 2026-03-09 36
#    WL-PL431 2026-03-10 20
#    WL-PL431 2026-03-11 34
#    WL-PL431 2026-03-12 16
#    WL-PL431 2026-03-13 20
#
# Hrzuska in df_soll
# LKW_KENNZ      DATUM  0
# OD-TS8050 2026-03-17 15
# PI-EN 900 2026-03-16 13
#  WL-PL431 2026-03-09 17
#  WL-PL431 2026-03-10 13
#  WL-PL431 2026-03-11 13
#  WL-PL431 2026-03-12 12
#
# Teme in df_ist
# KENNZ_CLEAN      DATUM  0
#   PI-EN 900 2026-03-19 11
#   PI-EN 900 2026-03-23  4
#    WL-PL431 2026-03-26  3
#    WL-PL431 2026-04-01  4
#
# Teme in df_soll
# LKW_KENNZ      DATUM  0
# OD-TS8050 2026-03-11  3
# OD-TS8050 2026-03-12  4
# OD-TS8050 2026-03-13  6
# PI-EN 444 2026-04-07  5
# PI-EN 900 2026-03-09 10
# PI-EN 900 2026-03-10  7
# PI-EN 900 2026-03-11  8
# PI-EN 900 2026-03-17  9
# PI-EN 900 2026-03-18  5
# PI-EN 900 2026-04-02  7
#  WL-PL431 2026-03-24  4
#  WL-PL431 2026-03-25  3
#  WL-PL431 2026-03-27  4
#  WL-PL431 2026-03-30  5
#  WL-PL431 2026-03-31  4

# %%
df_ist_merged
# Out:
#       Fahrer PIN          Fahrername  Formularnummer Formularbeschreibung  \
# 0         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 1         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 2         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 3         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 4         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# ...          ...                 ...             ...                  ...
# 2870      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2871      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2872      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2873      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2874      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
#
#             Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  \
# 0    2026-03-24 05:19:13        74                0  316550.025
# 1    2026-03-24 07:00:13         0                0  316550.025
# 2    2026-03-24 07:33:59         0                0  316565.680
# 3    2026-03-24 07:34:00         0                0  316565.680
# 4    2026-03-24 07:54:21         0                0  316568.980
# ...                  ...       ...              ...         ...
# 2870 2026-03-06 11:49:13       208                0  502860.415
# 2871 2026-03-06 11:59:39         0                0  502863.510
# 2872 2026-03-06 12:11:29         0                0  502863.755
# 2873 2026-03-06 12:37:22         0                0  502869.170
# 2874 2026-03-06 13:04:35         0                0  502874.385
#
#       Gesamtverbrauch  Tankfüllstand Breitengrad Längengrad  \
# 0                 0.0            0.0    53,66758    9,99266
# 1                 0.0            0.0    53,66757     9,9928
# 2                 0.0            0.0    53,58982    9,91377
# 3                 0.0            0.0    53,58982    9,91377
# 4                 0.0            0.0    53,58884    9,87736
# ...               ...            ...         ...        ...
# 2870              0.0            0.0    53,51717    9,96982
# 2871              0.0            0.0    53,52261    9,98925
# 2872              0.0            0.0     53,5228    9,98903
# 2873              0.0            0.0     53,5341    9,98237
# 2874              0.0            0.0    53,52344    9,98587
#
#                                                Position  \
# 0     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 2     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 3     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 4     DE - 22547 Hamburg (Lurup), Elbgaustraße (Ring...
# ...                                                 ...
# 2870  DE - 20457 Hamburg (Hamburg-Mitte), Köhlbrandb...
# 2871  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2872  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2873   DE - 20457 Hamburg (Hamburg-Mitte), Worthdamm 32
# 2874  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
#
#                           Fahrzeug       DATUM KENNZ_CLEAN   TOURNR
# 0     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 1     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 2     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 3     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 4     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# ...                            ...         ...         ...      ...
# 2870       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2871       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2872       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2873       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2874       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
#
# [2875 rows x 17 columns]

# %%
# Finale Statistik
gesamt = len(df_ist_merged)
mit_tour = df_ist_merged['TOURNR'].notna().sum()
ohne_tour = df_ist_merged['TOURNR'].isna().sum()

print(f"Gesamt Meldungen:       {gesamt}")
print(f"Mit Tournummer:         {mit_tour} ({mit_tour/gesamt*100:.1f}%)")
print(f"Ohne Tournummer (NaN):  {ohne_tour} ({ohne_tour/gesamt*100:.1f}%)")

# Lücken als separaten DataFrame speichern
df_luecken = df_ist_merged[df_ist_merged['TOURNR'].isna()].groupby(['Fahrername', 'KENNZ_CLEAN', 'DATUM']).size().reset_index()
df_luecken.columns = ['Fahrername', 'Kennzeichen', 'Datum', 'Anzahl_Meldungen']
df_luecken['Grund'] = 'Kein Soll-Eintrag vorhanden'
print(df_luecken)
# Out:
# Gesamt Meldungen:       2875
# Mit Tournummer:         2614 (90.9%)
# Ohne Tournummer (NaN):  261 (9.1%)
#                   Fahrername Kennzeichen       Datum  Anzahl_Meldungen  \
# 0   Calina, Florin Alexandru   OD-TS8050  2026-03-09                 4
# 1           Hesse, Sven-Erik   PI-EN 900  2026-03-03                 2
# 2          Hrzuska, Krzystof   OD-TS8050  2026-03-18                20
# 3          Hrzuska, Krzystof   OD-TS8050  2026-03-19                26
# 4          Hrzuska, Krzystof   OD-TS8050  2026-03-20                20
# 5          Hrzuska, Krzystof   PI-EN 444  2026-03-02                28
# 6          Hrzuska, Krzystof   PI-EN 444  2026-03-03                24
# 7          Hrzuska, Krzystof   PI-EN 444  2026-03-04                24
# 8          Hrzuska, Krzystof   PI-EN 444  2026-03-05                33
# 9          Hrzuska, Krzystof   PI-EN 444  2026-03-06                29
# 10         Hrzuska, Krzystof    WL-PL431  2026-03-13                20
# 11             Ledwina, Jens   OD-TS8044  2026-03-20                 1
# 12       Szmajdewicz, Marcin    WL-PL431  2026-03-24                 8
# 13           Teme, Abdoulaye   PI-EN 900  2026-03-19                11
# 14           Teme, Abdoulaye   PI-EN 900  2026-03-23                 4
# 15           Teme, Abdoulaye    WL-PL431  2026-03-26                 3
# 16           Teme, Abdoulaye    WL-PL431  2026-04-01                 4
#
#                           Grund
# 0   Kein Soll-Eintrag vorhanden
# 1   Kein Soll-Eintrag vorhanden
# 2   Kein Soll-Eintrag vorhanden
# 3   Kein Soll-Eintrag vorhanden
# 4   Kein Soll-Eintrag vorhanden
# 5   Kein Soll-Eintrag vorhanden
# 6   Kein Soll-Eintrag vorhanden
# 7   Kein Soll-Eintrag vorhanden
# 8   Kein Soll-Eintrag vorhanden
# 9   Kein Soll-Eintrag vorhanden
# 10  Kein Soll-Eintrag vorhanden
# 11  Kein Soll-Eintrag vorhanden
# 12  Kein Soll-Eintrag vorhanden
# 13  Kein Soll-Eintrag vorhanden
# 14  Kein Soll-Eintrag vorhanden
# 15  Kein Soll-Eintrag vorhanden
# 16  Kein Soll-Eintrag vorhanden

# %%
df_ist_merged["TOURNR"].nunique()
# Out:
# 200

# %% [markdown]
# ### Untersuchung ob Touren in df_soll sind aber nicht in df_ist

# %% [markdown]
# Es sind ca 40 Touren in df_soll aber nicht in df_ist.
# Im Kontrast dazu sind 14 Touren in df_ist aber nicht df_soll.
# Das bezieht sich jetzt auf das Mapping Datum Fahrer und Kennzeichen.
# Natürlich könnten einige der Fahrten die nicht in df_soll sind, Ersatzfahrten sein, weil ein Fahrer krank wurde.
# Allerdings denken wir, fürs erste ist es sinnvoll mit den Daten weiterzuarbeiten, die wir Tournummern-mäßig zuordnen konnten. Das sind 200.
# Mit diesen können wir das Geofencing ausprobeiren und starten.

# %%
df_soll["TOURNR"].nunique()
# Out:
# 240

# %%
# Welche Touren sind in df_soll aber nicht in df_ist?
touren_soll = set(df_soll['TOURNR'].unique())
touren_ist = set(df_ist_merged['TOURNR'].dropna().unique())

fehlende_touren = touren_soll - touren_ist

# Details zu den fehlenden Touren
df_fehlend = df_soll[df_soll['TOURNR'].isin(fehlende_touren)][['TOURNR', 'FAHRERNAME', 'LKW_KENNZ', 'DATUM']].drop_duplicates().sort_values('DATUM')

print(f"Fehlende Touren: {len(fehlende_touren)}")
print(df_fehlend.to_string(index=False))
# Out:
# Fehlende Touren: 40
#  TOURNR               FAHRERNAME LKW_KENNZ      DATUM
# H/42383          Giewon, Mariusz PI-EN 444 2026-03-02
# H/42416            Schulz, Frank PI-EN 900 2026-03-02
# H/42400          Giewon, Mariusz PI-EN 444 2026-03-03
# H/42415        Krüger, Alexander PI-EN 900 2026-03-03
# H/42412          Giewon, Mariusz PI-EN 444 2026-03-04
# H/42413           Staben, Volker     RW435 2026-03-04
# H/42427          Giewon, Mariusz PI-EN 444 2026-03-05
# H/42439          Giewon, Mariusz PI-EN 444 2026-03-06
# H/42429            Schulz, Frank PI-EN 900 2026-03-06
# H/42447            Schulz, Frank OD-TS8050 2026-03-09
# H/42449       Jorczik, Christian OD-TS8041 2026-03-09
# H/42452 Calina, Florin Alexandru OD-TS8046 2026-03-09
# H/42467           Staben, Volker     RW435 2026-03-10
# H/42493           Staben, Volker     RW435 2026-03-12
# H/42503            Sowa, Mariusz  WL-PL431 2026-03-13
# H/42533           Staben, Volker     RW435 2026-03-17
# H/42536      Szmajdewicz, Marcin OD-TS8050 2026-03-18
# H/42570                      NaN Leihwagen 2026-03-19
# H/42558           Staben, Volker     RW435 2026-03-19
# H/42547      Szmajdewicz, Marcin PI-EN 900 2026-03-19
# H/42549      Szmajdewicz, Marcin OD-TS8050 2026-03-19
# H/42561      Szmajdewicz, Marcin OD-TS8050 2026-03-20
# H/42564       Jorczik, Christian OD-TS8041 2026-03-20
# H/42571 Calina, Florin Alexandru PI-EN 900 2026-03-23
# H/42590          Teme, Abdoulaye  WL-PL431 2026-03-24
# H/42633           Staben, Volker     RW435 2026-03-25
# H/42638          Teme, Abdoulaye  WL-PL431 2026-03-25
# H/42657        Krüger, Alexander Plo-TS859 2026-03-31
# H/42695     Oelschlaeger, Marcel  WL-PL431 2026-04-01
# H/42701           Staben, Volker     RW435 2026-04-02
# H/42750         Stoffer, Andreas OD-TS8048 2026-04-07
# H/42746            Schulz, Frank OD-TS8050 2026-04-07
# H/42742            Ledwina, Jens Plö-TS857 2026-04-07
# H/42738            Borrs, Thomas Plö-TS853 2026-04-07
# H/42754            Sowa, Mariusz  WL-PL431 2026-04-07
# H/42730        Krüger, Alexander Plo-TS859 2026-04-07
# H/42722         Hesse, Sven-Erik Plo-TS856 2026-04-07
# H/42718     Oelschlaeger, Marcel PI-EN 900 2026-04-07
# H/42734       Jorczik, Christian OD-TS8041 2026-04-07
# H/42758          Teme, Abdoulaye PI-EN 444 2026-04-07

# %% [markdown]
# Sowa, Mariusz & Stoffer, Andreas, Frank Schulz und Staben Volker tauchen in df_ist nie auf
# 04.07. – massiver Ausfall - war in einzelmeldungsreport tatsächlich gar nicht inkludiert -> gar nicht in ist daten
# Staben, Volker fährt immer (RW435)  Kennzeichen taucht in df_ist nie auf
#
# -> ich würde nur mit den Zugeordneten touren weiter arbeiten

# %%
# Bestätigung: Wer ist gar nicht in df_ist?
print("In df_soll aber nie in df_ist:")
print(set(df_soll['FAHRERNAME'].dropna()) - set(df_ist['Fahrername'].unique()))

# Wie viele fehlende Touren pro Fahrer?
print("\nFehlende Touren pro Fahrer:")
print(df_fehlend.groupby('FAHRERNAME').size().sort_values(ascending=False))

# Wie viele fehlende Touren pro Datum?
print("\nFehlende Touren pro Datum:")
print(df_fehlend.groupby('DATUM').size().sort_values(ascending=False))
# Out:
# In df_soll aber nie in df_ist:
# {'Schulz, Frank', 'Staben, Volker', 'Stoffer, Andreas', 'Sowa, Mariusz'}
#
# Fehlende Touren pro Fahrer:
# FAHRERNAME
# Staben, Volker              7
# Giewon, Mariusz             5
# Schulz, Frank               4
# Szmajdewicz, Marcin         4
# Krüger, Alexander           3
# Jorczik, Christian          3
# Teme, Abdoulaye             3
# Oelschlaeger, Marcel        2
# Calina, Florin Alexandru    2
# Sowa, Mariusz               2
# Hesse, Sven-Erik            1
# Borrs, Thomas               1
# Ledwina, Jens               1
# Stoffer, Andreas            1
# dtype: int64
#
# Fehlende Touren pro Datum:
# DATUM
# 2026-04-07    10
# 2026-03-19     4
# 2026-03-09     3
# 2026-03-02     2
# 2026-03-20     2
# 2026-03-04     2
# 2026-03-03     2
# 2026-03-06     2
# 2026-03-25     2
# 2026-03-05     1
# 2026-03-12     1
# 2026-03-10     1
# 2026-03-18     1
# 2026-03-17     1
# 2026-03-13     1
# 2026-03-23     1
# 2026-03-24     1
# 2026-03-31     1
# 2026-04-01     1
# 2026-04-02     1
# dtype: int64

# %% [markdown]
# -->> Nur mit zugeorndeten Tournummern weiter arbeiten !

# %%
df_ist_merged
# Out:
#       Fahrer PIN          Fahrername  Formularnummer Formularbeschreibung  \
# 0         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 1         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 2         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# 3         8160.0  Jorczik, Christian            1651        Abfahrt Kunde
# 4         8160.0  Jorczik, Christian            1650        Ankunft Kunde
# ...          ...                 ...             ...                  ...
# 2870      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2871      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2872      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
# 2873      8180.0   Krüger, Alexander            1650        Ankunft Kunde
# 2874      8180.0   Krüger, Alexander            1651        Abfahrt Kunde
#
#             Meldungszeit  Richtung  Geschwindigkeit    KM-Stand  \
# 0    2026-03-24 05:19:13        74                0  316550.025
# 1    2026-03-24 07:00:13         0                0  316550.025
# 2    2026-03-24 07:33:59         0                0  316565.680
# 3    2026-03-24 07:34:00         0                0  316565.680
# 4    2026-03-24 07:54:21         0                0  316568.980
# ...                  ...       ...              ...         ...
# 2870 2026-03-06 11:49:13       208                0  502860.415
# 2871 2026-03-06 11:59:39         0                0  502863.510
# 2872 2026-03-06 12:11:29         0                0  502863.755
# 2873 2026-03-06 12:37:22         0                0  502869.170
# 2874 2026-03-06 13:04:35         0                0  502874.385
#
#       Gesamtverbrauch  Tankfüllstand Breitengrad Längengrad  \
# 0                 0.0            0.0    53,66758    9,99266
# 1                 0.0            0.0    53,66757     9,9928
# 2                 0.0            0.0    53,58982    9,91377
# 3                 0.0            0.0    53,58982    9,91377
# 4                 0.0            0.0    53,58884    9,87736
# ...               ...            ...         ...        ...
# 2870              0.0            0.0    53,51717    9,96982
# 2871              0.0            0.0    53,52261    9,98925
# 2872              0.0            0.0     53,5228    9,98903
# 2873              0.0            0.0     53,5341    9,98237
# 2874              0.0            0.0    53,52344    9,98587
#
#                                                Position  \
# 0     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 1     DE - 22419 Hamburg (Langenhorn), Essener Straß...
# 2     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 3     DE - 22525 Hamburg (Eimsbüttel), Lederstraße 3...
# 4     DE - 22547 Hamburg (Lurup), Elbgaustraße (Ring...
# ...                                                 ...
# 2870  DE - 20457 Hamburg (Hamburg-Mitte), Köhlbrandb...
# 2871  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2872  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
# 2873   DE - 20457 Hamburg (Hamburg-Mitte), Worthdamm 32
# 2874  DE - 20457 Hamburg (Hamburg-Mitte), Brandenbur...
#
#                           Fahrzeug       DATUM KENNZ_CLEAN   TOURNR
# 0     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 1     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 2     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 3     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# 4     OD-TS 8041 - Fahrzeugdetails  2026-03-24   OD-TS8041  H/42592
# ...                            ...         ...         ...      ...
# 2870       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2871       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2872       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2873       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
# 2874       TS859 - Fahrzeugdetails  2026-03-06   Plo-TS859  H/42432
#
# [2875 rows x 17 columns]

# %% [markdown]
# ### Arbeit an Übersichtlichkeit von df_soll

# %% [markdown]
# Hier ist auffällig:
# 1. Es gibt bei identischer Tournummer identiscche GEOX, GEOY und Ankunft aber verschiedene Abfahrten.
# Uns scheint die späteren Abfahrten machen mehr Sinn -> wir filtern bei Identischer Tournummer, GEOX, GEOY und Ankunft die stopps raus, die frühere Abfahrt haben.
#
# 2. In den Ist Daten stoppt der Plan nach der "letzten Warenausgabe". Bei den Soll daten stoppt der Plan nach Rückankunft beim Ausgangsort.
# Deshalb in Fällen wo bei einer Tour der erste und letzte Stopp identisch sind Filtern wir den letzten Stopp sodass wir dann besser mir Ist Daten vergleichen können.

# %%
df_soll
# Out:
#        TOURNR  LKW_KENNZ        FAHRERNAME     TOUR             ANKUNFT  \
# 0     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 1     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 2     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:49:00
# 3     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 07:41:00
# 4     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 08:31:00
# ...       ...        ...               ...      ...                 ...
# 2795  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:00:00
# 2796  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:57:00
# 2797  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 07:53:00
# 2798  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 09:52:00
# 2799  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 11:52:00
#
#                  ABFAHRT      GEOX      GEOY     STOPP_DAUER       DATUM
# 0    2026-03-02 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-03-02
# 1    2026-03-02 06:30:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 2    2026-03-02 07:19:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# 3    2026-03-02 08:11:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 4    2026-03-02 09:01:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# ...                  ...       ...       ...             ...         ...
# 2795 2026-04-07 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
# 2796 2026-04-07 07:27:00  10.09782  53.53610 0 days 00:30:00  2026-04-07
# 2797 2026-04-07 08:23:00   9.98632  53.52348 0 days 00:30:00  2026-04-07
# 2798 2026-04-07 10:22:00   9.51017  53.64711 0 days 00:30:00  2026-04-07
# 2799 2026-04-07 11:52:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
#
# [1991 rows x 10 columns]

# %% [markdown]
# Schauen wie oft tatsächlich zwei identische "Starts" sind:

# %%
dupe_groups = df_soll.groupby(['TOURNR', 'GEOX', 'GEOY', 'ANKUNFT']).size()
print(dupe_groups[dupe_groups > 1].sort_values(ascending=False))
# Out:
# TOURNR   GEOX     GEOY      ANKUNFT
# H/42374  9.98632  53.52348  2026-03-02 06:00:00    2
# H/42376  9.98632  53.52348  2026-03-02 06:00:00    2
# H/42379  9.99189  53.66737  2026-03-02 05:00:00    2
# H/42380  9.98632  53.52348  2026-03-02 06:00:00    2
# H/42383  9.98632  53.52348  2026-03-02 06:00:00    2
#                                                   ..
# H/42708  9.98632  53.52348  2026-04-01 06:00:00    2
# H/42718  9.98632  53.52348  2026-04-07 06:00:00    2
# H/42738  9.99189  53.66737  2026-04-07 05:00:00    2
# H/42742  9.99189  53.66737  2026-04-07 05:00:00    2
# H/42746  9.98632  53.52348  2026-04-07 06:00:00    2
# Length: 135, dtype: int64

# %%
# Sortiere nach ABFAHRT absteigend pro Gruppe
df_soll_sorted = df_soll.sort_values(['TOURNR', 'GEOX', 'GEOY', 'ANKUNFT', 'ABFAHRT'], ascending=[True, True, True, True, False])

# Behalte nur die erste (späteste ABFAHRT) pro Gruppe
df_filtered = df_soll_sorted.drop_duplicates(subset=['TOURNR', 'GEOX', 'GEOY', 'ANKUNFT'], keep='first')

print(f"Anzahl Duplikate entfernt: {len(df_soll) - len(df_filtered)}")
# Out:
# Anzahl Duplikate entfernt: 135

# %% [markdown]
# Hier sieht man dass das entfernen der Duplikate geklappt hat

# %%
df_filtered
# Out:
#        TOURNR  LKW_KENNZ        FAHRERNAME     TOUR             ANKUNFT  \
# 1     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 3     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 07:41:00
# 5     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 09:23:00
# 2     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 06:49:00
# 4     H/42374  Plo-TS856  Hesse, Sven-Erik  H/42374 2026-03-02 08:31:00
# ...       ...        ...               ...      ...                 ...
# 2798  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 09:52:00
# 2795  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:00:00
# 2797  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 07:53:00
# 2799  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 11:52:00
# 2796  H/42758  PI-EN 444   Teme, Abdoulaye  H/42758 2026-04-07 06:57:00
#
#                  ABFAHRT      GEOX      GEOY     STOPP_DAUER       DATUM
# 1    2026-03-02 06:30:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 3    2026-03-02 08:11:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 5    2026-03-02 09:23:00   9.98632  53.52348 0 days 00:00:00  2026-03-02
# 2    2026-03-02 07:19:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# 4    2026-03-02 09:01:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# ...                  ...       ...       ...             ...         ...
# 2798 2026-04-07 10:22:00   9.51017  53.64711 0 days 00:30:00  2026-04-07
# 2795 2026-04-07 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
# 2797 2026-04-07 08:23:00   9.98632  53.52348 0 days 00:30:00  2026-04-07
# 2799 2026-04-07 11:52:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
# 2796 2026-04-07 07:27:00  10.09782  53.53610 0 days 00:30:00  2026-04-07
#
# [1856 rows x 10 columns]

# %%
df_filtered[df_filtered['TOURNR'] == "H/42380"]
# Out:
#      TOURNR  LKW_KENNZ                FAHRERNAME     TOUR             ANKUNFT  \
# 47  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 07:59:00
# 46  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 06:00:00
# 48  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 09:59:00
# 50  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 12:42:00
# 49  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 11:19:00
#
#                ABFAHRT     GEOX      GEOY     STOPP_DAUER       DATUM
# 47 2026-03-02 08:29:00  9.51017  53.64711 0 days 00:30:00  2026-03-02
# 46 2026-03-02 06:30:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 48 2026-03-02 10:29:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 50 2026-03-02 12:42:00  9.98632  53.52348 0 days 00:00:00  2026-03-02
# 49 2026-03-02 11:49:00  9.99022  53.72624 0 days 00:30:00  2026-03-02

# %% [markdown]
# Jetzt ist allerdings alles nach Tournummer nach GEOX geordnet, also machen wir das mal zurück

# %%
df_final = df_filtered.sort_values(['TOURNR', 'DATUM', 'ABFAHRT']).reset_index(drop=True)

# %%
df_final[df_final['TOURNR'] == "H/42380"]
# Out:
#      TOURNR  LKW_KENNZ                FAHRERNAME     TOUR             ANKUNFT  \
# 42  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 06:00:00
# 43  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 07:59:00
# 44  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 09:59:00
# 45  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 11:19:00
# 46  H/42380  OD-TS8046  Calina, Florin Alexandru  H/42380 2026-03-02 12:42:00
#
#                ABFAHRT     GEOX      GEOY     STOPP_DAUER       DATUM
# 42 2026-03-02 06:30:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 43 2026-03-02 08:29:00  9.51017  53.64711 0 days 00:30:00  2026-03-02
# 44 2026-03-02 10:29:00  9.98632  53.52348 0 days 00:30:00  2026-03-02
# 45 2026-03-02 11:49:00  9.99022  53.72624 0 days 00:30:00  2026-03-02
# 46 2026-03-02 12:42:00  9.98632  53.52348 0 days 00:00:00  2026-03-02

# %% [markdown]
# Jetzt sind touren wieder zeitmäßig sortiert.
# Nun schauen wir wann die Anfangs- und stopppunkte wirklich identisch sind.

# %%
# Pro Tour die Koordinaten vom ersten und letzten Stopp holen
tour_starts = df_final.groupby('TOURNR').first()[['GEOX', 'GEOY']]
tour_ends = df_final.groupby('TOURNR').last()[['GEOX', 'GEOY']]

# Vergleichen ob Start == Ende
tour_starts.columns = ['start_x', 'start_y']
tour_ends.columns = ['end_x', 'end_y']
comparison = tour_starts.join(tour_ends)

matches = ((comparison['start_x'] == comparison['end_x']) & (comparison['start_y'] == comparison['end_y'])).sum()

print(f"{matches} Touren starten und enden am selben Ort")
# Out:
# 236 Touren starten und enden am selben Ort

# %%
nicht_identisch = comparison[
    (comparison['start_x'] != comparison['end_x']) | 
    (comparison['start_y'] != comparison['end_y'])
]
touren_ohne_kreis = nicht_identisch.index.tolist()
print("Touren ohne Kreis:", touren_ohne_kreis)
# Out:
# Touren ohne Kreis: ['H/42459', 'H/42468', 'H/42510', 'H/42633']

# %% [markdown]
# Ausprobieren der Touren die nicht identischen Start und Stop haben.

# %%
df_final[df_final['TOURNR'] == "H/42459"]
# Out:
#       TOURNR  LKW_KENNZ         FAHRERNAME     TOUR             ANKUNFT  \
# 434  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 06:00:00
# 435  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 06:30:00
# 436  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 07:00:00
# 437  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 07:30:00
# 438  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 08:00:00
# 439  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 08:30:00
# 440  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 09:00:00
# 441  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 09:30:00
# 442  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 10:00:00
# 443  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 10:30:00
# 444  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 11:00:00
# 445  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 11:30:00
# 446  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 12:00:00
# 447  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 13:00:00
# 448  H/42459  Plo-TS859  Krüger, Alexander  H/42459 2026-03-10 12:30:00
#
#                 ABFAHRT     GEOX      GEOY     STOPP_DAUER       DATUM
# 434 2026-03-10 06:30:00  9.98632  53.52348 0 days 00:30:00  2026-03-10
# 435 2026-03-10 07:00:00  9.99383  53.54751 0 days 00:30:00  2026-03-10
# 436 2026-03-10 07:30:00  0.00000   0.00000 0 days 00:30:00  2026-03-10
# 437 2026-03-10 08:00:00  9.98632  53.52348 0 days 00:30:00  2026-03-10
# 438 2026-03-10 08:30:00  9.98213  53.53497 0 days 00:30:00  2026-03-10
# 439 2026-03-10 09:00:00  0.00000   0.00000 0 days 00:30:00  2026-03-10
# 440 2026-03-10 09:30:00  9.98213  53.53497 0 days 00:30:00  2026-03-10
# 441 2026-03-10 10:00:00  9.98632  53.52348 0 days 00:30:00  2026-03-10
# 442 2026-03-10 10:30:00  0.00000   0.00000 0 days 00:30:00  2026-03-10
# 443 2026-03-10 11:00:00  9.98632  53.52348 0 days 00:30:00  2026-03-10
# 444 2026-03-10 11:30:00  0.00000   0.00000 0 days 00:30:00  2026-03-10
# 445 2026-03-10 12:00:00  9.98213  53.53497 0 days 00:30:00  2026-03-10
# 446 2026-03-10 12:30:00  9.98632  53.52348 0 days 00:30:00  2026-03-10
# 447 2026-03-10 13:00:00  9.98632  53.52348 0 days 00:00:00  2026-03-10
# 448 2026-03-10 13:00:00  9.99383  53.54751 0 days 00:30:00  2026-03-10

# %% [markdown]
# Die Fahrt macht wieder keinen Sinn, Koordinaten fehlen.... -> Probleme bei Daten wieder

# %% [markdown]
# Dennoch in den 236 Fällen wo Start und Endpunkt identisch sind werde ich den Endpunkt rausfiltern, sodass wir dann Starten können die Fälle zu vergleichen.

# %%
kreis_touren = comparison[
    (comparison['start_x'] == comparison['end_x']) & 
    (comparison['start_y'] == comparison['end_y'])
].index

df_clean = df_final.copy()
for tour in kreis_touren:
    tour_data = df_clean[df_clean['TOURNR'] == tour]
    if len(tour_data) > 1:
        df_clean = df_clean[~((df_clean['TOURNR'] == tour) &  (df_clean.index == tour_data.index[-1]))]

df_soll_final = df_clean.copy()  # Finaler Data frame

print(f"Letzte Stopps entfernt für {len(kreis_touren)} Touren")
# Out:
# Letzte Stopps entfernt für 236 Touren

# %%
df_soll_final
# Out:
#        TOURNR  LKW_KENNZ           FAHRERNAME     TOUR             ANKUNFT  \
# 0     H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374 2026-03-02 06:00:00
# 1     H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374 2026-03-02 06:49:00
# 2     H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374 2026-03-02 07:41:00
# 3     H/42374  Plo-TS856     Hesse, Sven-Erik  H/42374 2026-03-02 08:31:00
# 5     H/42375  OD-TS8050  Szmajdewicz, Marcin  H/42375 2026-03-02 06:00:00
# ...       ...        ...                  ...      ...                 ...
# 1849  H/42754   WL-PL431        Sowa, Mariusz  H/42754 2026-04-07 09:05:00
# 1851  H/42758  PI-EN 444      Teme, Abdoulaye  H/42758 2026-04-07 06:00:00
# 1852  H/42758  PI-EN 444      Teme, Abdoulaye  H/42758 2026-04-07 06:57:00
# 1853  H/42758  PI-EN 444      Teme, Abdoulaye  H/42758 2026-04-07 07:53:00
# 1854  H/42758  PI-EN 444      Teme, Abdoulaye  H/42758 2026-04-07 09:52:00
#
#                  ABFAHRT      GEOX      GEOY     STOPP_DAUER       DATUM
# 0    2026-03-02 06:30:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 1    2026-03-02 07:19:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# 2    2026-03-02 08:11:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# 3    2026-03-02 09:01:00   9.99383  53.54751 0 days 00:30:00  2026-03-02
# 5    2026-03-02 06:30:00   9.98632  53.52348 0 days 00:30:00  2026-03-02
# ...                  ...       ...       ...             ...         ...
# 1849 2026-04-07 09:35:00   9.98213  53.53497 0 days 00:30:00  2026-04-07
# 1851 2026-04-07 06:00:00   9.98632  53.52348 0 days 00:00:00  2026-04-07
# 1852 2026-04-07 07:27:00  10.09782  53.53610 0 days 00:30:00  2026-04-07
# 1853 2026-04-07 08:23:00   9.98632  53.52348 0 days 00:30:00  2026-04-07
# 1854 2026-04-07 10:22:00   9.51017  53.64711 0 days 00:30:00  2026-04-07
#
# [1620 rows x 10 columns]

# %% [markdown]
# Beispiel einer gecleanten soll Tour

# %%
df_soll_final[df_soll_final['TOURNR'] == "H/42460"]
# Out:
#       TOURNR  LKW_KENNZ          FAHRERNAME     TOUR             ANKUNFT  \
# 449  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 05:00:00
# 450  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 06:56:00
# 451  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 08:03:00
# 452  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 08:38:00
# 453  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 09:31:00
# 454  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 10:33:00
# 455  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 11:26:00
# 456  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 12:16:00
# 457  H/42460  OD-TS8041  Jorczik, Christian  H/42460 2026-03-10 12:51:00
#
#                 ABFAHRT      GEOX      GEOY     STOPP_DAUER       DATUM
# 449 2026-03-10 06:45:00   9.99189  53.66737 0 days 01:45:00  2026-03-10
# 450 2026-03-10 07:21:00  10.04632  53.68627 0 days 00:25:00  2026-03-10
# 451 2026-03-10 08:28:00  10.37411  53.80550 0 days 00:25:00  2026-03-10
# 452 2026-03-10 09:03:00  10.40753  53.79811 0 days 00:25:00  2026-03-10
# 453 2026-03-10 09:56:00  10.23939  53.67382 0 days 00:25:00  2026-03-10
# 454 2026-03-10 10:58:00  10.19781  53.48664 0 days 00:25:00  2026-03-10
# 455 2026-03-10 11:51:00  10.01992  53.53592 0 days 00:25:00  2026-03-10
# 456 2026-03-10 12:41:00  10.11836  53.58145 0 days 00:25:00  2026-03-10
# 457 2026-03-10 13:16:00  10.11864  53.60523 0 days 00:25:00  2026-03-10
